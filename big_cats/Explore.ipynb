# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
data_dir = '../Data/big_cats/'
tab1 = pd.read_excel(data_dir + 'BiochemicalChangesinCKDAbbrevColours20160828.xlsx', sheetname='NormalFelidsn=1319')

# %%
tab1
# Out:
#                 ID ARKS Number     Animal Name           Species       Date  \
# 0              473      900485           Omaha      Snow leopard 1995-10-30
# 1               64      900485           Omaha      Snow leopard 1995-08-28
# 2              471      790036             Ali            Jaguar 1996-07-18
# 3              532      850083           Shiva             Tiger 1996-11-13
# 4              318      920185         Chester             Tiger 2000-11-16
# 5              335      930431           Nonah   Clouded leopard 2000-09-06
# 6               57      900484         Prafula      Snow leopard 1999-03-17
# 7              329      930431           Nonah   Clouded leopard 1995-02-10
# 8              310      920185         Chester             Tiger 1994-09-28
# 9               62      900484         Prafula      Snow leopard 2003-09-10
# 10            1725      A10244            Kato             Tiger 2007-04-02
# ...

# %%
tab1[tab1['ARKS Number']==900485]
# Out:
#         ID ARKS Number Animal Name       Species       Date  Low USG?  \
# 0      473      900485       Omaha  Snow leopard 1995-10-30     False
# 1       64      900485       Omaha  Snow leopard 1995-08-28     False
# 17      65      900485       Omaha  Snow leopard 1996-10-11     False
# 18      70      900485       Omaha  Snow leopard 2000-11-01     False
# 20      66      900485       Omaha  Snow leopard 1997-01-08     False
# 25      67      900485       Omaha  Snow leopard 1997-05-14     False
# 39      69      900485       Omaha  Snow leopard 2000-01-18     False
# 163     68      900485       Omaha  Snow leopard 1997-10-03     False
# 1096  1615      900485       Omaha  Snow leopard 2004-05-29     False
# 1184    71      900485       Omaha  Snow leopard 2001-04-11     False
#
#      urea (mmol/L) Uraemia Creatinine (umol/L) Hypercreatinaemia?  \
# 0              7.5   False                 170              False
# ...

# %%
tab2 = pd.read_excel('BiochemicalChangesinCKDAbbrevColours20160828.xlsx', sheetname='CKDn=163')

# %%
tab2[tab2['ARKS Number']==850083]
# Out:
#     ID ARKS Number Animal Name Species       Date  Low USG? urea (mmol/L)  \
# 1  306      850083       Shiva   Tiger 2002-02-27      True          36.9
# 6  305      850083       Shiva   Tiger 2001-06-29      True          11.4
# 8  308      850083       Shiva   Tiger 2002-03-08      True          30.3
#
#      Uraemia Creatinine (umol/L)   Hypercreatinaemia?  ... CK (U/L) ALP (U/L)  \
# 1  azotaemia                 654  hypercreatininaemia  ...      345        32
# 6      False                 385  hypercreatininaemia  ...      301        29
# 8  azotaemia                 786  hypercreatininaemia  ...      390        28
#
#   ALT (U/L) AST Amylase  - Cholesterol (mmol/L) Bilirubin  \
# 1        57  48       -  -                    -         -
# 6       104  88       -  -                    -         -
# 8        84  41       -  -                    -         -
#
#   Serum/plasma appearance                                          Comments:
# ...

# %%
tab2
# Out:
#        ID ARKS Number  Animal Name          Species       Date  Low USG?  \
# 0    1604      890254       Mangar     Snow leopard 2008-12-29     False
# 1     306      850083        Shiva            Tiger 2002-02-27      True
# 2    1430      A70193      Mujambi             Lion 2011-12-23     False
# 3      37      920185      Chester            Tiger 2000-05-05      True
# 4      36      920185      Chester            Tiger 1999-09-17      True
# 5      35      920185      Chester            Tiger 1999-09-15      True
# 6     305      850083        Shiva            Tiger 2001-06-29      True
# 7     467      A20021       Cantik      Fishing cat 2004-04-16     False
# 8     308      850083        Shiva            Tiger 2002-03-08      True
# 9      77      930430        Samar  Clouded leopard 2004-03-04      True
# 10     76      930430        Samar  Clouded leopard 2003-12-23      True
# 11    516      700022          Gai            Tiger 1990-01-02     False
# ...

# %%
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))

# %%
intersection(tab2['ARKS Number'].values, tab1['ARKS Number'].values)
# Out:
# ['A20062',
#  890114,
#  900485,
#  880014,
#  890254,
#  'A20021',
#  890000,
#  890004,
#  790038,
#  900248,
#  970009,
#  'A10083',
#  980123,
#  960029,
#  'A49219',
#  'B00021',
#  850083,
#  'A10081',
#  960035,
#  'A40004',
#  'Koyukon',
#  950061,
#  980910,
#  'A49221',
#  'A10134',
#  980912,
#  930228,
#  930229,
#  750005,
#  670005,
#  950075,
#  'A10080',
#  950077,
#  'A80047',
#  950079,
#  950078,
#  'A50433',
#  'B09072',
#  830014,
#  960069,
#  800074,
#  'A60598',
#  990293,
#  921430,
#  'A40080',
#  840026,
#  960093,
#  960094,
#  960095,
#  'A40003',
#  780001,
#  840034,
#  'A50189',
#  'A70551',
#  'A70193',
#  999023,
#  999024,
#  999025,
#  'A10174',
#  999027,
#  980084,
#  870008,
#  920185,
#  'A40005',
#  950908,
#  930430]

# %%
tab2[tab2['ARKS Number']==900485]
# Out:
#        ID ARKS Number Animal Name       Species       Date  Low USG?  \
# 115    72      900485       Omaha  Snow leopard 2003-09-11      True
# 136  1606      900485       Omaha  Snow leopard 2004-05-16     False
#
#     urea (mmol/L)    Uraemia Creatinine (umol/L)   Hypercreatinaemia?  \
# 115          19.7  azotaemia                 330  hypercreatininaemia
# 136          12.8      False                 306  hypercreatininaemia
#
#     Total Plasma Protein (g/L) hyperproteinaemia Serum Albumin (g/L)  \
# 115                         73            normal                  35
# 136                         74            normal                  36
#
#     hyperalbuminaemia Globulins (g/L) Changes in globulins Haematocrit (%)  \
# 115            normal              38               normal              50
# 136            normal              37               normal              28
#
#                Anaemic? Potassium (mmol/L) Changes in potassium  \
# ...

# %%
tab1[tab1['ARKS Number']==900485]
# Out:
#         ID ARKS Number Animal Name       Species       Date  Low USG?  \
# 0      473      900485       Omaha  Snow leopard 1995-10-30     False
# 1       64      900485       Omaha  Snow leopard 1995-08-28     False
# 17      65      900485       Omaha  Snow leopard 1996-10-11     False
# 18      70      900485       Omaha  Snow leopard 2000-11-01     False
# 20      66      900485       Omaha  Snow leopard 1997-01-08     False
# 25      67      900485       Omaha  Snow leopard 1997-05-14     False
# 39      69      900485       Omaha  Snow leopard 2000-01-18     False
# 163     68      900485       Omaha  Snow leopard 1997-10-03     False
# 1096  1615      900485       Omaha  Snow leopard 2004-05-29     False
# 1184    71      900485       Omaha  Snow leopard 2001-04-11     False
#
#      urea (mmol/L) Uraemia Creatinine (umol/L) Hypercreatinaemia?  \
# 0              7.5   False                 170              False
# ...
