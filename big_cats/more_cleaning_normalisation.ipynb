# %%
# this notebook follows on from GROUP_mergeData_filterData_prepForML

# %% [markdown]
# <div style='color: FloralWhite; padding: 2rem; background-image: radial-gradient(farthest-corner at 40px 40px,
#       #f35 0%, #43e 100%); font-weight: 500'>
# <h2 style='padding: 0; margin-bottom: 1rem; margin-top:0;'> NEXT STEPS </h2>
# <li>impute missing values</li>
# <li>look at pattern and % missing values for analytes we're interested in for new features</li>
# <li>case/control distributions of key analytes {done}</li>
# <li>read the stats from Rachel's thesis</li>
# <li>one-hot encoding of categorical columns {done} </li>
# <li> make features from grad, intercept of linear fit {done}</li>
# <li> We are basically geniuses </li>
# <li>PCA, try some basic models</li>
#     </div>

# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.impute import KNNImputer
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_csv('../Data/big_cats/processed_data/filtered_data_26052021.csv')
data.head()
# Out:
#   ARKS Number  Acute kidney failure Age at Death  CKD - cause of mortality  \
# 0     Koyukon                 False          NaN                     False
# 1     Koyukon                 False          NaN                     False
# 2     Koyukon                 False          NaN                     False
# 3     Koyukon                 False          NaN                     False
# 4     Koyukon                 False          NaN                     False
#
#    CKD - co-morbidity Date  of Birth  Infection  Neoplasia  Neurological  \
# 0                True     1974-01-01      False      False         False
# 1                True     1974-01-01      False      False         False
# 2                True     1974-01-01      False      False         False
# 3                True     1974-01-01      False      False         False
# 4                True     1974-01-01      False      False         False
#
#    Old Age debility  Respiratory/Cardiovascular   Sex  \
# 0             False                       False  male
# 1             False                       False  male
# 2             False                       False  male
# 3             False                       False  male
# 4             False                       False  male
#
#       Species (common name)  Trauma                 Date  \
# 0  Northern (Canadian) Lynx   False  1987-02-02 00:00:00
# 1  Northern (Canadian) Lynx   False  1988-05-28 00:00:00
# 2  Northern (Canadian) Lynx   False  1988-06-01 00:00:00
# 3  Northern (Canadian) Lynx   False  1988-11-08 00:00:00
# 4  Northern (Canadian) Lynx   False  1987-02-19 00:00:00
#
#    haem: RBC (x 10^12/L)  haem: haemoglobin (g/L)  haem: HCT (%)  \
# 0                    NaN                      NaN            NaN
# 1                    NaN                      NaN            NaN
# 2                    NaN                      NaN            NaN
# 3                    NaN                      NaN            NaN
# 4                    NaN                      NaN            NaN
#
#    haem: Total Protein (refractometer)  haem: leukocyte count (x10^9/L)  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#    haem: neutrophils (%)  haem: neutrophils (band)  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
#    haem: neutrophils(seg) (x10^9/L)  haem: lymphocytes (x10^9/L)  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    haem: lymphocytes  (%)  haem: monocytes (x10^9/L)  haem: monocytes (%)  \
# 0                     NaN                        NaN                  NaN
# 1                     NaN                        NaN                  NaN
# 2                     NaN                        NaN                  NaN
# 3                     NaN                        NaN                  NaN
# 4                     NaN                        NaN                  NaN
#
#    haem: eosinophils  (x10^9/L)  haem: eosinophils (%)  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#   haem: estimated platelets x 10^9/L (Hi)  haem: MCV (fL)  haem: MCHC (g/L)  \
# 0                                     NaN             NaN               NaN
# 1                                     NaN             NaN               NaN
# 2                                     NaN             NaN               NaN
# 3                                     NaN             NaN               NaN
# 4                                     NaN             NaN               NaN
#
#    haem: MCH (pg) biochem: Low USG?  biochem: BUN (mmol/L)  \
# 0             NaN             False                    NaN
# 1             NaN             False                    NaN
# 2             NaN              True                  11.85
# 3             NaN             False                  12.51
# 4             NaN               NaN                    NaN
#
#   biochem: Hypercreatininaemia?  biochem: Creatinine (umol/L)  \
# 0                         False                           NaN
# 1                         False                           NaN
# 2                          True                         319.0
# 3                         False                           NaN
# 4                           NaN                           NaN
#
#    biochem: Total Plasma Protein (g/L)  biochem: Serum Albumin (g/L)  \
# 0                                  NaN                           NaN
# 1                                 89.0                           NaN
# 2                                  NaN                           NaN
# 3                                 70.0                          36.0
# 4                                  NaN                           NaN
#
#    biochem: Globulins (g/L) biochem: Anaemic? <25  biochem: Haematocrit (%)  \
# 0                       NaN                 False                      27.0
# 1                       NaN                 False                      41.0
# 2                       NaN                 False                       NaN
# 3                      34.0                 False                      45.0
# 4                       NaN                   NaN                       NaN
#
#    biochem: Potassium (mmol/L)  biochem: Calcium (mmol/L)  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   biochem: Hyperphosphataemia? >2_9 to 3  biochem: Phosphate (mmol/L)  \
# 0                                  False                          NaN
# 1                                  False                          NaN
# 2                                  False                          NaN
# 3                                  False                          NaN
# 4                                    NaN                          NaN
#
#    biochem: Sodium (mmol/L)  biochem: Chloride (mmol/L)  biochem: Bicarbonate  \
# 0                       NaN                         NaN                   NaN
# 1                       NaN                         NaN                   NaN
# 2                       NaN                         NaN                   NaN
# 3                       NaN                         NaN                   NaN
# 4                       NaN                         NaN                   NaN
#
#    biochem: Glucose  biochem: CK (U/L)  biochem: ALP (U/L)  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2               NaN             1432.0                 NaN
# 3               NaN              102.0                13.0
# 4               NaN                NaN                 NaN
#
#    biochem: ALT (U/L)  biochem: AST  biochem: Amylase  \
# 0                 NaN           NaN               NaN
# 1                 NaN           NaN               NaN
# 2                 NaN           NaN               NaN
# 3                46.0          29.0               NaN
# 4                 NaN           NaN               NaN
#
#    biochem: Cholesterol (mmol/L) biochem: Bilirubin  \
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
#
#    urine: Urine Specific Gravity urine: Low USG? urine: Azotaemia?  \
# 0                            NaN           False             False
# 1                          1.044           False             False
# 2                          1.028            True              True
# 3                            NaN             NaN               NaN
# 4                          1.060           False             False
#
#    urine: Urine protein (g/L)  urine: urine creatinine (umol/l)  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#    urine: Protein:creatinine ratio urine: Proteinuric UPC  greater 0:4  \
# 0                              NaN                               False
# 1                              NaN                               False
# 2                              NaN                               False
# 3                              NaN                                 NaN
# 4                              NaN                               False
#
#   urine: glucose (Multistix) urine: bilirubin (Multistix)  \
# 0                      trace                          nil
# 1                        NaN                          NaN
# 2                        nil                          nil
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#   urine: ketones (Multistix) urine: blood (Hb -Multistix)  urine: pH  \
# 0                        nil                          nil        6.5
# 1                        NaN                          NaN        6.0
# 2                        nil                          nil        6.5
# 3                        NaN                          NaN        NaN
# 4                        NaN                          NaN        7.0
#
#   urine: protein (Multistix) urine: Positive urine culture  \
# 0                         1+                         False
# 1                         1+                         False
# 2                         1+                         False
# 3                        NaN                           NaN
# 4                         3+                         False
#
#   urine: leukocytes (/cumm)x urine: blood (RBC/ ul) (haematuriax urine: Lipid  \
# 0                        NaN                                 NaN        False
# 1                        NaN                                 NaN        False
# 2                        NaN                                 NaN        False
# 3                        NaN                                 NaN          NaN
# 4                        NaN                                 NaN        False
#
#   urine: Casts urine: Epith cells urine: Crystals urine: Organisms  \
# 0        False              False           False            False
# 1        False              False           False            False
# 2        False              False           False            False
# 3          NaN                NaN             NaN              NaN
# 4        False              False           False            False
#
#   urine: Contaminants?  usg_maxed_out  urine: blood haemolysed     Date dt  \
# 0                False              0                        0  1987-02-02
# 1                False              0                        0  1988-05-28
# 2                False              0                        0  1988-06-01
# 3                  NaN              0                        0  1988-11-08
# 4                False              1                        0  1987-02-19
#
#   Date of Birth dt                  age at visit  num visits
# 0       1974-01-01  4780 days 00:00:00.000000000           5
# 1       1974-01-01  5261 days 00:00:00.000000000           5
# 2       1974-01-01  5265 days 00:00:00.000000000           5
# 3       1974-01-01  5425 days 00:00:00.000000000           5
# 4       1974-01-01  4797 days 00:00:00.000000000           5

# %%
len(data)
# Out:
# 1438

# %%
missing_dict = dict(data.isna().sum().sort_values(ascending=False))

# %%
missing_dict
# Out:
# {'urine: urine creatinine (umol/l)': 1377,
#  'urine: Urine protein (g/L)': 1377,
#  'urine: Protein:creatinine ratio': 1370,
#  'haem: MCH (pg)': 1370,
#  'haem: MCV (fL)': 1320,
#  'haem: MCHC (g/L)': 1311,
#  'haem: neutrophils (band)': 1307,
#  'haem: estimated platelets x 10^9/L (Hi)': 1254,
#  'haem: eosinophils (%)': 1245,
#  'haem: monocytes (%)': 1229,
#  'haem: lymphocytes  (%)': 1208,
#  'urine: leukocytes (/cumm)x': 1195,
#  'urine: blood (RBC/ ul) (haematuriax': 1190,
#  'haem: Total Protein (refractometer)': 1189,
#  'haem: neutrophils (%)': 1151,
#  'haem: eosinophils  (x10^9/L)': 1149,
#  'haem: RBC (x 10^12/L)': 1148,
#  'haem: neutrophils(seg) (x10^9/L)': 1127,
#  'haem: monocytes (x10^9/L)': 1108,
#  'biochem: Amylase': 1099,
#  'haem: lymphocytes (x10^9/L)': 1093,
#  'haem: haemoglobin (g/L)': 1005,
#  'haem: leukocyte count (x10^9/L)': 992,
#  'haem: HCT (%)': 983,
#  'biochem: Bicarbonate': 887,
#  'biochem: Cholesterol (mmol/L)': 870,
#  'urine: bilirubin (Multistix)': 841,
#  'urine: ketones (Multistix)': 827,
#  'urine: glucose (Multistix)': 815,
#  'urine: blood (Hb -Multistix)': 800,
#  'urine: pH': 781,
#  'urine: protein (Multistix)': 758,
#  'urine: Urine Specific Gravity': 717,
#  'biochem: Glucose': 701,
#  'biochem: Bilirubin': 695,
#  'urine: Contaminants?': 676,
#  'urine: Low USG?': 676,
#  'urine: Organisms': 676,
#  'urine: Azotaemia?': 676,
#  'urine: Proteinuric UPC  greater 0:4': 676,
#  'urine: Positive urine culture': 676,
#  'urine: Lipid': 676,
#  'urine: Casts': 676,
#  'urine: Epith cells': 676,
#  'urine: Crystals': 676,
#  'biochem: Chloride (mmol/L)': 649,
#  'biochem: Sodium (mmol/L)': 581,
#  'biochem: Potassium (mmol/L)': 567,
#  'biochem: Calcium (mmol/L)': 562,
#  'biochem: Phosphate (mmol/L)': 548,
#  'biochem: CK (U/L)': 529,
#  'biochem: AST': 519,
#  'biochem: ALP (U/L)': 515,
#  'biochem: Haematocrit (%)': 498,
#  'biochem: Globulins (g/L)': 452,
#  'biochem: Serum Albumin (g/L)': 439,
#  'biochem: ALT (U/L)': 438,
#  'biochem: Total Plasma Protein (g/L)': 394,
#  'biochem: Creatinine (umol/L)': 392,
#  'biochem: BUN (mmol/L)': 389,
#  'biochem: Hypercreatininaemia?': 367,
#  'biochem: Hyperphosphataemia? >2_9 to 3': 367,
#  'biochem: Anaemic? <25': 367,
#  'biochem: Low USG?': 367,
#  'Age at Death': 134,
#  'Date  of Birth': 1,
#  'age at visit': 1,
#  'Date of Birth dt': 1,
#  'Neoplasia': 0,
#  'Infection': 0,
#  'Old Age debility': 0,
#  'CKD - co-morbidity': 0,
#  'Acute kidney failure': 0,
#  'CKD - cause of mortality': 0,
#  'Neurological': 0,
#  'num visits': 0,
#  'Respiratory/Cardiovascular': 0,
#  'Sex': 0,
#  'Species (common name)': 0,
#  'Trauma': 0,
#  'Date': 0,
#  'usg_maxed_out': 0,
#  'urine: blood haemolysed': 0,
#  'Date dt': 0,
#  'ARKS Number': 0}

# %%
missing_percent = data.isna().sum().sort_values(ascending=False).divide(len(data))

# %%
dict(missing_percent)
# Out:
# {'urine: urine creatinine (umol/l)': 0.9575799721835884,
#  'urine: Urine protein (g/L)': 0.9575799721835884,
#  'urine: Protein:creatinine ratio': 0.952712100139082,
#  'haem: MCH (pg)': 0.952712100139082,
#  'haem: MCV (fL)': 0.9179415855354659,
#  'haem: MCHC (g/L)': 0.911682892906815,
#  'haem: neutrophils (band)': 0.9089012517385258,
#  'haem: estimated platelets x 10^9/L (Hi)': 0.8720445062586927,
#  'haem: eosinophils (%)': 0.8657858136300417,
#  'haem: monocytes (%)': 0.8546592489568846,
#  'haem: lymphocytes  (%)': 0.8400556328233658,
#  'urine: leukocytes (/cumm)x': 0.8310152990264256,
#  'urine: blood (RBC/ ul) (haematuriax': 0.827538247566064,
#  'haem: Total Protein (refractometer)': 0.8268428372739917,
#  'haem: neutrophils (%)': 0.8004172461752433,
#  'haem: eosinophils  (x10^9/L)': 0.7990264255910987,
#  'haem: RBC (x 10^12/L)': 0.7983310152990264,
#  'haem: neutrophils(seg) (x10^9/L)': 0.7837273991655076,
#  'haem: monocytes (x10^9/L)': 0.7705146036161336,
#  'biochem: Amylase': 0.7642559109874826,
#  'haem: lymphocytes (x10^9/L)': 0.7600834492350487,
#  'haem: haemoglobin (g/L)': 0.6988873435326843,
#  'haem: leukocyte count (x10^9/L)': 0.6898470097357441,
#  'haem: HCT (%)': 0.6835883171070932,
#  'biochem: Bicarbonate': 0.6168289290681502,
#  'biochem: Cholesterol (mmol/L)': 0.6050069541029207,
#  'urine: bilirubin (Multistix)': 0.5848400556328234,
#  'urine: ketones (Multistix)': 0.5751043115438108,
#  'urine: glucose (Multistix)': 0.566759388038943,
#  'urine: blood (Hb -Multistix)': 0.5563282336578581,
#  'urine: pH': 0.5431154381084841,
#  'urine: protein (Multistix)': 0.5271210013908206,
#  'urine: Urine Specific Gravity': 0.49860917941585536,
#  'biochem: Glucose': 0.4874826147426982,
#  'biochem: Bilirubin': 0.48331015299026425,
#  'urine: Contaminants?': 0.47009735744089015,
#  'urine: Low USG?': 0.47009735744089015,
#  'urine: Organisms': 0.47009735744089015,
#  'urine: Azotaemia?': 0.47009735744089015,
#  'urine: Proteinuric UPC  greater 0:4': 0.47009735744089015,
#  'urine: Positive urine culture': 0.47009735744089015,
#  'urine: Lipid': 0.47009735744089015,
#  'urine: Casts': 0.47009735744089015,
#  'urine: Epith cells': 0.47009735744089015,
#  'urine: Crystals': 0.47009735744089015,
#  'biochem: Chloride (mmol/L)': 0.4513212795549374,
#  'biochem: Sodium (mmol/L)': 0.4040333796940195,
#  'biochem: Potassium (mmol/L)': 0.39429763560500697,
#  'biochem: Calcium (mmol/L)': 0.3908205841446453,
#  'biochem: Phosphate (mmol/L)': 0.3810848400556328,
#  'biochem: CK (U/L)': 0.3678720445062587,
#  'biochem: AST': 0.3609179415855355,
#  'biochem: ALP (U/L)': 0.3581363004172462,
#  'biochem: Haematocrit (%)': 0.3463143254520167,
#  'biochem: Globulins (g/L)': 0.3143254520166898,
#  'biochem: Serum Albumin (g/L)': 0.30528511821974963,
#  'biochem: ALT (U/L)': 0.3045897079276773,
#  'biochem: Total Plasma Protein (g/L)': 0.27399165507649514,
#  'biochem: Creatinine (umol/L)': 0.2726008344923505,
#  'biochem: BUN (mmol/L)': 0.2705146036161335,
#  'biochem: Hypercreatininaemia?': 0.25521557719054244,
#  'biochem: Hyperphosphataemia? >2_9 to 3': 0.25521557719054244,
#  'biochem: Anaemic? <25': 0.25521557719054244,
#  'biochem: Low USG?': 0.25521557719054244,
#  'Age at Death': 0.09318497913769123,
#  'Date  of Birth': 0.0006954102920723226,
#  'age at visit': 0.0006954102920723226,
#  'Date of Birth dt': 0.0006954102920723226,
#  'Neoplasia': 0.0,
#  'Infection': 0.0,
#  'Old Age debility': 0.0,
#  'CKD - co-morbidity': 0.0,
#  'Acute kidney failure': 0.0,
#  'CKD - cause of mortality': 0.0,
#  'Neurological': 0.0,
#  'num visits': 0.0,
#  'Respiratory/Cardiovascular': 0.0,
#  'Sex': 0.0,
#  'Species (common name)': 0.0,
#  'Trauma': 0.0,
#  'Date': 0.0,
#  'usg_maxed_out': 0.0,
#  'urine: blood haemolysed': 0.0,
#  'Date dt': 0.0,
#  'ARKS Number': 0.0}

# %%
data_more_than1visit = data[data['num visits'] >1 ]
len(data_more_than1visit)
# Out:
# 1404

# %%
dict(data_more_than1visit.isna().sum().sort_values(ascending=False).divide(len(data_more_than1visit)))
# Out:
# {'urine: urine creatinine (umol/l)': 0.9572649572649573,
#  'urine: Urine protein (g/L)': 0.9572649572649573,
#  'haem: MCH (pg)': 0.9529914529914529,
#  'urine: Protein:creatinine ratio': 0.9522792022792023,
#  'haem: MCV (fL)': 0.9173789173789174,
#  'haem: MCHC (g/L)': 0.9109686609686609,
#  'haem: neutrophils (band)': 0.9088319088319088,
#  'haem: estimated platelets x 10^9/L (Hi)': 0.8696581196581197,
#  'haem: eosinophils (%)': 0.8646723646723646,
#  'haem: monocytes (%)': 0.8532763532763533,
#  'haem: lymphocytes  (%)': 0.8383190883190883,
#  'urine: leukocytes (/cumm)x': 0.8297720797720798,
#  'urine: blood (RBC/ ul) (haematuriax': 0.8254985754985755,
#  'haem: Total Protein (refractometer)': 0.8240740740740741,
#  'haem: neutrophils (%)': 0.7977207977207977,
#  'haem: eosinophils  (x10^9/L)': 0.7962962962962963,
#  'haem: RBC (x 10^12/L)': 0.7948717948717948,
#  'haem: neutrophils(seg) (x10^9/L)': 0.7799145299145299,
#  'haem: monocytes (x10^9/L)': 0.7670940170940171,
#  'biochem: Amylase': 0.7606837606837606,
#  'haem: lymphocytes (x10^9/L)': 0.7564102564102564,
#  'haem: haemoglobin (g/L)': 0.6937321937321937,
#  'haem: leukocyte count (x10^9/L)': 0.6844729344729344,
#  'haem: HCT (%)': 0.6780626780626781,
#  'biochem: Bicarbonate': 0.613960113960114,
#  'biochem: Cholesterol (mmol/L)': 0.6054131054131054,
#  'urine: bilirubin (Multistix)': 0.5811965811965812,
#  'urine: ketones (Multistix)': 0.5719373219373219,
#  'urine: glucose (Multistix)': 0.5633903133903134,
#  'urine: blood (Hb -Multistix)': 0.5527065527065527,
#  'urine: pH': 0.5384615384615384,
#  'urine: protein (Multistix)': 0.5227920227920227,
#  'urine: Urine Specific Gravity': 0.4943019943019943,
#  'biochem: Glucose': 0.4886039886039886,
#  'biochem: Bilirubin': 0.4829059829059829,
#  'urine: Contaminants?': 0.4658119658119658,
#  'urine: Low USG?': 0.4658119658119658,
#  'urine: Organisms': 0.4658119658119658,
#  'urine: Azotaemia?': 0.4658119658119658,
#  'urine: Proteinuric UPC  greater 0:4': 0.4658119658119658,
#  'urine: Positive urine culture': 0.4658119658119658,
#  'urine: Lipid': 0.4658119658119658,
#  'urine: Casts': 0.4658119658119658,
#  'urine: Epith cells': 0.4658119658119658,
#  'urine: Crystals': 0.4658119658119658,
#  'biochem: Chloride (mmol/L)': 0.4465811965811966,
#  'biochem: Sodium (mmol/L)': 0.400997150997151,
#  'biochem: Potassium (mmol/L)': 0.391025641025641,
#  'biochem: Calcium (mmol/L)': 0.38603988603988604,
#  'biochem: Phosphate (mmol/L)': 0.37606837606837606,
#  'biochem: CK (U/L)': 0.36324786324786323,
#  'biochem: AST': 0.35683760683760685,
#  'biochem: ALP (U/L)': 0.3561253561253561,
#  'biochem: Haematocrit (%)': 0.3433048433048433,
#  'biochem: Globulins (g/L)': 0.3076923076923077,
#  'biochem: ALT (U/L)': 0.3041310541310541,
#  'biochem: Serum Albumin (g/L)': 0.3005698005698006,
#  'biochem: Total Plasma Protein (g/L)': 0.2727920227920228,
#  'biochem: Creatinine (umol/L)': 0.2706552706552707,
#  'biochem: BUN (mmol/L)': 0.2692307692307692,
#  'biochem: Hyperphosphataemia? >2_9 to 3': 0.254985754985755,
#  'biochem: Hypercreatininaemia?': 0.254985754985755,
#  'biochem: Anaemic? <25': 0.254985754985755,
#  'biochem: Low USG?': 0.254985754985755,
#  'Age at Death': 0.0868945868945869,
#  'Acute kidney failure': 0.0,
#  'Neurological': 0.0,
#  'Neoplasia': 0.0,
#  'Infection': 0.0,
#  'Respiratory/Cardiovascular': 0.0,
#  'CKD - cause of mortality': 0.0,
#  'CKD - co-morbidity': 0.0,
#  'Date  of Birth': 0.0,
#  'Old Age debility': 0.0,
#  'num visits': 0.0,
#  'Sex': 0.0,
#  'Species (common name)': 0.0,
#  'Trauma': 0.0,
#  'Date': 0.0,
#  'age at visit': 0.0,
#  'usg_maxed_out': 0.0,
#  'urine: blood haemolysed': 0.0,
#  'Date dt': 0.0,
#  'Date of Birth dt': 0.0,
#  'ARKS Number': 0.0}

# %%
# look at pattern of missing values for key analytes

# %%
key_features = ['biochem: Creatinine (umol/L)', 'biochem: BUN (mmol/L)', 'urine: Urine Specific Gravity']

# %%
data_more_than1visit['num key features missing'] = data_more_than1visit[key_features].isna().sum(axis=1)
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_more_than1visit
# Out:
#      ARKS Number  Acute kidney failure Age at Death  CKD - cause of mortality  \
# 0        Koyukon                 False          NaN                     False
# 1        Koyukon                 False          NaN                     False
# 2        Koyukon                 False          NaN                     False
# 3        Koyukon                 False          NaN                     False
# 4        Koyukon                 False          NaN                     False
# ...          ...                   ...          ...                       ...
# 1431      B20036                 False      3y3m20d                     False
# 1432      B20036                 False      3y3m20d                     False
# 1435         pet                 False          NaN                      True
# 1436         pet                 False          NaN                      True
# 1437         pet                 False          NaN                      True
#
#       CKD - co-morbidity Date  of Birth  Infection  Neoplasia  Neurological  \
# 0                   True     1974-01-01      False      False         False
# 1                   True     1974-01-01      False      False         False
# 2                   True     1974-01-01      False      False         False
# 3                   True     1974-01-01      False      False         False
# 4                   True     1974-01-01      False      False         False
# ...                  ...            ...        ...        ...           ...
# 1431               False     2009-11-27      False      False          True
# 1432               False     2009-11-27      False      False          True
# 1435               False     1991-07-01      False      False         False
# 1436               False     1991-07-01      False      False         False
# 1437               False     1991-07-01      False      False         False
#
#       Old Age debility  Respiratory/Cardiovascular   Sex  \
# 0                False                       False  male
# 1                False                       False  male
# 2                False                       False  male
# 3                False                       False  male
# 4                False                       False  male
# ...                ...                         ...   ...
# 1431             False                       False  male
# 1432             False                       False  male
# 1435             False                       False  male
# 1436             False                       False  male
# 1437             False                       False  male
#
#          Species (common name)  Trauma                 Date  \
# 0     Northern (Canadian) Lynx   False  1987-02-02 00:00:00
# 1     Northern (Canadian) Lynx   False  1988-05-28 00:00:00
# 2     Northern (Canadian) Lynx   False  1988-06-01 00:00:00
# 3     Northern (Canadian) Lynx   False  1988-11-08 00:00:00
# 4     Northern (Canadian) Lynx   False  1987-02-19 00:00:00
# ...                        ...     ...                  ...
# 1431                   Cheetah   False  2013-03-15 00:00:00
# 1432                   Cheetah   False  2013-03-16 00:00:00
# 1435              Bengal Tiger   False  1992-02-27 00:00:00
# 1436              Bengal Tiger   False  1992-07-30 00:00:00
# 1437              Bengal Tiger   False  1992-07-28 00:00:00
#
#       haem: RBC (x 10^12/L)  haem: haemoglobin (g/L)  haem: HCT (%)  \
# 0                       NaN                      NaN            NaN
# 1                       NaN                      NaN            NaN
# 2                       NaN                      NaN            NaN
# 3                       NaN                      NaN            NaN
# 4                       NaN                      NaN            NaN
# ...                     ...                      ...            ...
# 1431                    NaN                      NaN            NaN
# 1432                    NaN                      NaN            NaN
# 1435                    NaN                      NaN           29.0
# 1436                   4.19                     85.0           26.4
# 1437                    NaN                      NaN            NaN
#
#       haem: Total Protein (refractometer)  haem: leukocyte count (x10^9/L)  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
# ...                                   ...                              ...
# 1431                                  NaN                              NaN
# 1432                                  NaN                              NaN
# 1435                                 10.5                              NaN
# 1436                                  NaN                             12.7
# 1437                                  NaN                              NaN
#
#       haem: neutrophils (%)  haem: neutrophils (band)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ...                     ...                       ...
# 1431                    NaN                       NaN
# 1432                    NaN                       NaN
# 1435                    NaN                       NaN
# 1436                    NaN                       NaN
# 1437                    NaN                       NaN
#
#       haem: neutrophils(seg) (x10^9/L)  haem: lymphocytes (x10^9/L)  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 1431                               NaN                          NaN
# 1432                               NaN                          NaN
# 1435                               NaN                          NaN
# 1436                               NaN                          NaN
# 1437                               NaN                          NaN
#
#       haem: lymphocytes  (%)  haem: monocytes (x10^9/L)  haem: monocytes (%)  \
# 0                        NaN                        NaN                  NaN
# 1                        NaN                        NaN                  NaN
# 2                        NaN                        NaN                  NaN
# 3                        NaN                        NaN                  NaN
# 4                        NaN                        NaN                  NaN
# ...                      ...                        ...                  ...
# 1431                     NaN                        NaN                  NaN
# 1432                     NaN                        NaN                  NaN
# 1435                     NaN                        NaN                  NaN
# 1436                     NaN                        NaN                  NaN
# 1437                     NaN                        NaN                  NaN
#
#       haem: eosinophils  (x10^9/L)  haem: eosinophils (%)  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ...                            ...                    ...
# 1431                           NaN                    NaN
# 1432                           NaN                    NaN
# 1435                           NaN                    NaN
# 1436                           NaN                    NaN
# 1437                           NaN                    NaN
#
#      haem: estimated platelets x 10^9/L (Hi)  haem: MCV (fL)  \
# 0                                        NaN             NaN
# 1                                        NaN             NaN
# 2                                        NaN             NaN
# 3                                        NaN             NaN
# 4                                        NaN             NaN
# ...                                      ...             ...
# 1431                                     NaN             NaN
# 1432                                     NaN             NaN
# 1435                                     NaN             NaN
# 1436                                     NaN            63.0
# 1437                                     NaN             NaN
#
#       haem: MCHC (g/L)  haem: MCH (pg) biochem: Low USG?  \
# 0                  NaN             NaN             False
# 1                  NaN             NaN             False
# 2                  NaN             NaN              True
# 3                  NaN             NaN             False
# 4                  NaN             NaN               NaN
# ...                ...             ...               ...
# 1431               NaN             NaN             False
# 1432               NaN             NaN             False
# 1435               NaN             NaN              True
# 1436             323.0             NaN             False
# 1437               NaN             NaN             False
#
#       biochem: BUN (mmol/L) biochem: Hypercreatininaemia?  \
# 0                       NaN                         False
# 1                       NaN                         False
# 2                     11.85                          True
# 3                     12.51                         False
# 4                       NaN                           NaN
# ...                     ...                           ...
# 1431                  11.20                         False
# 1432                  11.80                         False
# 1435                  83.00                          True
# 1436                  82.20                          True
# 1437                  84.00                          True
#
#       biochem: Creatinine (umol/L)  biochem: Total Plasma Protein (g/L)  \
# 0                              NaN                                  NaN
# 1                              NaN                                 89.0
# 2                            319.0                                  NaN
# 3                              NaN                                 70.0
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 1431                         240.0                                 65.0
# 1432                         236.0                                 64.0
# 1435                         698.0                                  NaN
# 1436                         725.0                                 85.0
# 1437                         692.0                                 83.0
#
#       biochem: Serum Albumin (g/L)  biochem: Globulins (g/L)  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                             36.0                      34.0
# 4                              NaN                       NaN
# ...                            ...                       ...
# 1431                          36.0                      29.0
# 1432                          34.0                      30.0
# 1435                           NaN                       NaN
# 1436                          37.0                      48.0
# 1437                          35.0                      48.0
#
#      biochem: Anaemic? <25  biochem: Haematocrit (%)  \
# 0                    False                      27.0
# 1                    False                      41.0
# 2                    False                       NaN
# 3                    False                      45.0
# 4                      NaN                       NaN
# ...                    ...                       ...
# 1431                 False                      51.0
# 1432                 False                      48.0
# 1435                 False                      29.0
# 1436                 False                      26.0
# 1437                 False                       NaN
#
#       biochem: Potassium (mmol/L)  biochem: Calcium (mmol/L)  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1431                          4.3                       2.50
# 1432                          4.2                       2.62
# 1435                          NaN                        NaN
# 1436                          4.4                       2.87
# 1437                          4.8                       2.79
#
#      biochem: Hyperphosphataemia? >2_9 to 3  biochem: Phosphate (mmol/L)  \
# 0                                     False                          NaN
# 1                                     False                          NaN
# 2                                     False                          NaN
# 3                                     False                          NaN
# 4                                       NaN                          NaN
# ...                                     ...                          ...
# 1431                                  False                         1.90
# 1432                                  False                         1.63
# 1435                                  False                          NaN
# 1436                                  False                          NaN
# 1437                                  False                          NaN
#
#       biochem: Sodium (mmol/L)  biochem: Chloride (mmol/L)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 1431                     161.0                       121.0
# 1432                     159.0                       126.0
# 1435                       NaN                         NaN
# 1436                     147.0                         NaN
# 1437                     156.0                         NaN
#
#       biochem: Bicarbonate  biochem: Glucose  biochem: CK (U/L)  \
# 0                      NaN               NaN                NaN
# 1                      NaN               NaN                NaN
# 2                      NaN               NaN             1432.0
# 3                      NaN               NaN              102.0
# 4                      NaN               NaN                NaN
# ...                    ...               ...                ...
# 1431                  20.0               NaN              496.0
# 1432                  18.0               5.7                NaN
# 1435                   NaN               NaN                NaN
# 1436                   NaN               7.6              227.0
# 1437                   NaN               7.8                NaN
#
#       biochem: ALP (U/L)  biochem: ALT (U/L)  biochem: AST  biochem: Amylase  \
# 0                    NaN                 NaN           NaN               NaN
# 1                    NaN                 NaN           NaN               NaN
# 2                    NaN                 NaN           NaN               NaN
# 3                   13.0                46.0          29.0               NaN
# 4                    NaN                 NaN           NaN               NaN
# ...                  ...                 ...           ...               ...
# 1431                 5.0               115.0          76.0               NaN
# 1432                 9.0                86.0          53.0               NaN
# 1435                 NaN                 NaN           NaN               NaN
# 1436                 NaN                42.0          29.0               NaN
# 1437                 NaN                 NaN           NaN               NaN
#
#       biochem: Cholesterol (mmol/L) biochem: Bilirubin  \
# 0                               NaN                NaN
# 1                               NaN                NaN
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                               NaN                NaN
# ...                             ...                ...
# 1431                            4.8                  1
# 1432                            NaN                  4
# 1435                            NaN                NaN
# 1436                            NaN                NaN
# 1437                            NaN                NaN
#
#       urine: Urine Specific Gravity urine: Low USG? urine: Azotaemia?  \
# 0                               NaN           False             False
# 1                             1.044           False             False
# 2                             1.028            True              True
# 3                               NaN             NaN               NaN
# 4                             1.060           False             False
# ...                             ...             ...               ...
# 1431                            NaN             NaN               NaN
# 1432                            NaN             NaN               NaN
# 1435                          1.015            True              True
# 1436                            NaN             NaN               NaN
# 1437                            NaN             NaN               NaN
#
#       urine: Urine protein (g/L)  urine: urine creatinine (umol/l)  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 1431                         NaN                               NaN
# 1432                         NaN                               NaN
# 1435                         NaN                               NaN
# 1436                         NaN                               NaN
# 1437                         NaN                               NaN
#
#       urine: Protein:creatinine ratio urine: Proteinuric UPC  greater 0:4  \
# 0                                 NaN                               False
# 1                                 NaN                               False
# 2                                 NaN                               False
# 3                                 NaN                                 NaN
# 4                                 NaN                               False
# ...                               ...                                 ...
# 1431                              NaN                                 NaN
# 1432                              NaN                                 NaN
# 1435                              NaN                               False
# 1436                              NaN                                 NaN
# 1437                              NaN                                 NaN
#
#      urine: glucose (Multistix) urine: bilirubin (Multistix)  \
# 0                         trace                          nil
# 1                           NaN                          NaN
# 2                           nil                          nil
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 1431                        NaN                          NaN
# 1432                        NaN                          NaN
# 1435                        NaN                          NaN
# 1436                        NaN                          NaN
# 1437                        NaN                          NaN
#
#      urine: ketones (Multistix) urine: blood (Hb -Multistix)  urine: pH  \
# 0                           nil                          nil        6.5
# 1                           NaN                          NaN        6.0
# 2                           nil                          nil        6.5
# 3                           NaN                          NaN        NaN
# 4                           NaN                          NaN        7.0
# ...                         ...                          ...        ...
# 1431                        NaN                          NaN        NaN
# 1432                        NaN                          NaN        NaN
# 1435                        NaN                          NaN        6.0
# 1436                        NaN                          NaN        NaN
# 1437                        NaN                          NaN        NaN
#
#      urine: protein (Multistix) urine: Positive urine culture  \
# 0                            1+                         False
# 1                            1+                         False
# 2                            1+                         False
# 3                           NaN                           NaN
# 4                            3+                         False
# ...                         ...                           ...
# 1431                        NaN                           NaN
# 1432                        NaN                           NaN
# 1435                         3+                         False
# 1436                        NaN                           NaN
# 1437                        NaN                           NaN
#
#      urine: leukocytes (/cumm)x urine: blood (RBC/ ul) (haematuriax  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
# ...                         ...                                 ...
# 1431                        NaN                                 NaN
# 1432                        NaN                                 NaN
# 1435                        NaN                                 NaN
# 1436                        NaN                                 NaN
# 1437                        NaN                                 NaN
#
#      urine: Lipid urine: Casts urine: Epith cells urine: Crystals  \
# 0           False        False              False           False
# 1           False        False              False           False
# 2           False        False              False           False
# 3             NaN          NaN                NaN             NaN
# 4           False        False              False           False
# ...           ...          ...                ...             ...
# 1431          NaN          NaN                NaN             NaN
# 1432          NaN          NaN                NaN             NaN
# 1435        False        False              False           False
# 1436          NaN          NaN                NaN             NaN
# 1437          NaN          NaN                NaN             NaN
#
#      urine: Organisms urine: Contaminants?  usg_maxed_out  \
# 0               False                False              0
# 1               False                False              0
# 2               False                False              0
# 3                 NaN                  NaN              0
# 4               False                False              1
# ...               ...                  ...            ...
# 1431              NaN                  NaN              0
# 1432              NaN                  NaN              0
# 1435            False                False              0
# 1436              NaN                  NaN              0
# 1437              NaN                  NaN              0
#
#       urine: blood haemolysed     Date dt Date of Birth dt  \
# 0                           0  1987-02-02       1974-01-01
# 1                           0  1988-05-28       1974-01-01
# 2                           0  1988-06-01       1974-01-01
# 3                           0  1988-11-08       1974-01-01
# 4                           0  1987-02-19       1974-01-01
# ...                       ...         ...              ...
# 1431                        0  2013-03-15       2009-11-27
# 1432                        0  2013-03-16       2009-11-27
# 1435                        0  1992-02-27       1991-07-01
# 1436                        0  1992-07-30       1991-07-01
# 1437                        0  1992-07-28       1991-07-01
#
#                       age at visit  num visits  num key features missing
# 0     4780 days 00:00:00.000000000           5                         3
# 1     5261 days 00:00:00.000000000           5                         2
# 2     5265 days 00:00:00.000000000           5                         0
# 3     5425 days 00:00:00.000000000           5                         2
# 4     4797 days 00:00:00.000000000           5                         2
# ...                            ...         ...                       ...
# 1431  1204 days 00:00:00.000000000           7                         1
# 1432  1205 days 00:00:00.000000000           7                         1
# 1435   241 days 00:00:00.000000000           3                         0
# 1436   395 days 00:00:00.000000000           3                         1
# 1437   393 days 00:00:00.000000000           3                         1
#
# [1404 rows x 86 columns]

# %%
data_more_than1visit['num key features missing'].hist()

# %%
# look at cases and controls

# %%
cases = data_more_than1visit[data_more_than1visit['CKD - cause of mortality'] == True]
controls = data_more_than1visit[data_more_than1visit['CKD - cause of mortality'] == False]

# %%
len(cases)
# Out:
# 650

# %%
len(controls)
# Out:
# 754

# %%
for feature in key_features:
    fig, ax0 = plt.subplots(nrows=1, ncols=1)
    ax0.hist(cases[feature], density=True, histtype='bar', label='cases')
    ax0.hist(controls[feature], density=True, histtype='bar', label='controls')
    ax0.legend(prop={'size': 10})
    ax0.set_title(feature)

# %%
for feature in key_features:
    plt.hist(cases[feature], label = 'cases', stacked=True, histtype='bar', density = True)
    plt.hist(controls[feature], label = 'controls', stacked=True, histtype='bar', density = True)
    plt.title(feature)
    plt.legend()
    plt.show()

# %% [markdown]
# <div style='color: FloralWhite; padding: 2rem; background-image: radial-gradient(farthest-corner at 40px 40px,
#       #008080 0%, #43e 100%); font-weight: 500'>
# <h2 style='padding: 0; margin-bottom: 1rem; margin-top:0;'> PREPARING FOR PCA </h2>
# <li>Choose features based on % missing</li>
# <li> Make sure all chosen features are clean (some have less than signs) {done}</li>
# <li> convert dtypes to be what we think they should be  {done} </li>
# <li> Feature engineering of ordinal variables {done}</li>
# <li>Impute remaining contnuous features {done} </li>
# <li> Clean species {it's fine} </li>
# <li> One hot encode {done} </li>
# <li> Normalise features (min/max scaling) {done}</li>
# <li> PC motherfucking A WE ARE HEREEEEE </li>
#
# </div>

# %% [markdown]
# ## Clean some features of things we don't want

# %%
for col in list(data_more_than1visit.select_dtypes(include=['object']).columns):
    print(col)
    print(data_more_than1visit[col].unique())
    print()
# Out:
# ARKS Number
# ['Koyukon' '780127' '800014MZ' '920519' '980010' '980014' '999028'
#  'A39042' 'A50003' 'A79192' '780049' '900959' '930045' '960093' '990948'
#  'K0095' '200003' '670005' '720019' '730023' '730024' '750011' '760022'
#  '770005' '770006' '780001' '790025' '790026' '790035' '790036' '790036MZ'
#  '790037' '790038' '800015' '800017' '800029' '810034' '810041' '810044'
#  '810053' '810057' '820014' '820029' '830014' '830025' '840019' '840025'
#  '840026' '840033' '840034' '850007' '850083' '850101' '860057' '860081'
#  '870008' '880014' '880045' '880074' '880075' '890000' '890004' '890114'
#  '890254' '890290' '900248' '900249' '900484' '900485' '910080' '910517'
#  '920185' '920259' '920260' '920453' '920534' '921189' '921430' '930228'
#  '930229' '930230' '930430' '930431' '940101' '950061' '950062' '950075'
#  '950076' '950077' '950078' '950079' '950908' '960035' '960069' '960094'
#  '960095' '960142' '960259' '960461' '960996' '970005' '970007' '970008'
#  '970620' '980004' '980081' '980123' '980508' '980864' '980910' '980912'
#  '990092' '999022' '999023' '999024' '999025' '999026' '999027' 'A00005'
#  'A00045' 'A00482' 'A00906' 'A02063' 'A02064' 'A06001' 'A10010' 'A10080'
#  'A10081' 'A10083' 'A10174' 'A10253' 'A20021' 'A20046' 'A20047' 'A20062'
#  'A20067' 'A20545' 'A20745' 'A30035' 'A40001' 'A40002' 'A40152' 'A49219'
#  'A49221' 'A50002' 'A60570' 'A80047' 'A80050' 'A80581' 'B09072' 'B20032'
#  'B20036' 'pet']
#
# Age at Death
# [nan '16y1m15d' '16y3m13d' '21y7m15d' '17y7m6d' '9y5m0d' '10y7m4d'
#  '22y6m26d' '15y1m6d' '22y7m3d' '9y5m5d' '19y0m22d' '22y0m19d' '21y4m3d'
#  '17y0m14d' '18y10m6d' '16y5m29d' '17y7m25d' '21y1m12d' '17y3m10d'
#  '20y3m28d' '20y6m14d' '18y6m29d' '21y10m8d' '16y11m22d' '18y5m11d'
#  '10y7m8d' '15y6m1d' '19y5m29d' '15y11m19d' '18y0m12d' '17y5m14d'
#  '14y11m5d' '4y3m24d' '9y6m14d' '19y8m0d' '18y8m2d' '23y0m0d' '14y7m5d'
#  '19y11m11d' '9y11m2d' '15y7m23d' '14y9m25d' '12y0m20d' '17y5m27d'
#  '14y2m7d' '16y6m12d' '19y8m25d' '16y9m23d' '21y1m29d' '13y2m14d'
#  '14y3m27d' '19y8m23d' '15y10m0d' '21y4m6d' '20y10m20d' '21y1m27d'
#  '19y8m29d' '21y3m13d' '15y4m27d' '19y4m13d' '18y3m9d' '15y4m9d'
#  '6y11m16d' '14y3m6d' '17y4m29d' '16y8m0d' '12y0m25d' '17y5m3d' '18y11m6d'
#  '17y6m17d' '15y11m14d' '19y1m13d' '10y2m29d' '14y1m23d' '18y1m18d'
#  '13y4m18d' '13y7m29d' '10y6m11d' '17y3m24d' '4y10m25d' '18y1m23d'
#  '25y9m16d' '13y5m14d' '9y6m7d' '19y1m15d' '7y5m25d' '17y4m12d' '16y6m10d'
#  '18y4m13d' '18y0m4d' '14y3m4d' '13y2m12d' '9y7m27d' '13y3m1d' '14y3m22d'
#  '9y6m13d' '12y9m24d' '10y11m6d' '11y8m21d' '13y11m1d' '16y7m7d'
#  '13y5m10d' '10y8m19d' '14y7m6d' '10y3m24d' '9y9m21d' '10y1m0d' '9y3m28d'
#  '13y8m15d' '13y5m8d' '14y8m4d' '15y4m0d' '7y4m10d' '13y7m12d' '14y8m20d'
#  '15y8m17d' '14y6m11d' '11y1m7d' '8y10m18d' '15y0m11d' '21y6m3d'
#  '18y7m23d' '18y11m26d' '5y9m7d' '9y10m19d' '8y6m22d' '11y5m25d' '1y4m14d'
#  '4y0m22d' '3y5m5d' '16y7m29d' '12y8m24d' '7y8m18d' '3y3m20d']
#
# Date  of Birth
# ['1974-01-01' '1977-04-27' '1980-12-23' '1991-11-30' '1984-06-30'
#  '1997-01-06' '1999-11-02' '2003-05-12' '2007-09-19' '1978-02-07'
#  '1990-11-27' '1981-01-24' '1995-05-30' '1995-10-26' '1967-01-01'
#  '1993-01-01' '1967-01-22' '1972-07-21' '1973-05-11' '1973-11-02'
#  '1975-11-20' '1976-08-05' '1977-08-27' '1977-07-05' '1978-03-26'
#  '1979-12-30' '1979-02-07' '1979-03-01' '1978-05-25' '1980-01-06'
#  '1980-12-01' '1978-11-08' '1981-01-16' '1981-02-27' '1981-10-01'
#  '1980-03-20' '1973-02-22' '1982-12-22' '1982-04-24' '1983-03-24'
#  '1983-12-05' '1984-12-28' '1980-10-30' '1983-12-01' '1984-02-13'
#  '1983-06-04' '1985-09-07' '1984-07-31' '1986-12-20' '1986-01-31'
#  '1987-06-11' '1983-04-18' '1988-10-09' '1986-02-05' '1980-02-27'
#  '1981-10-21' '1987-09-28' '1989-03-29' '1989-06-01' '1988-08-12'
#  '1988-06-03' '1989-07-12' '1989-11-12' '1988-12-07' '1983-06-18'
#  '1990-01-24' '1990-11-01' '1992-11-08' '1975-10-10' '1992-09-12'
#  '1983-07-01' '1990-07-18' '1990-06-17' '1994-11-02' '1994-12-22'
#  '1988-03-09' '1988-07-29' '1991-05-12' '1993-09-22' '1991-12-16'
#  '1994-05-18' '1985-10-16' '1994-08-15' '1991-04-28' '1996-11-15'
#  '1985-06-30' '1996-06-15' '1990-07-27' '1994-06-21' '1998-10-23'
#  '1997-07-06' '1995-10-03' '1992-09-07' '1998-10-22' '1994-12-30'
#  '1996-09-14' '1995-12-01' '1996-09-18' '1996-01-02' '1996-04-21'
#  '2000-11-21' '1997-11-24' '2000-09-14' '2000-12-31' '2003-03-22'
#  '2002-05-12' '2005-06-05' '2000-07-29' '1999-07-20' '2002-01-12'
#  '1988-10-22' '2002-03-30' '1999-09-29' '1997-03-02' '1990-09-06'
#  '2002-02-14' '2004-09-11' '2006-10-28' '2008-08-05' '2008-08-07'
#  '1996-12-04' '2000-08-22' '2005-03-26' '2009-11-27' '1991-07-01']
#
# Sex
# ['male' 'female']
#
# Species (common name)
# ['Northern (Canadian) Lynx' 'Cheetah' 'Leopard Cat' 'Persian Leopard'
#  'Lion' 'Asiatic Lion' 'African Lion' 'Jaguar' 'Sumatran Tiger' 'Leopard'
#  'Tiger' 'Bobcat' 'Ocelot' 'Cougar' "Temminck's Golden Cat" 'Serval'
#  'Caracal' 'Jaguarundi' 'Snow Leopard' 'Fishing Cat' 'Tiger (White)'
#  'Siberian Tiger' 'Clouded Leopard' 'Bengal Tiger' 'Bengal Tiger (white)']
#
# Date
# ['1987-02-02 00:00:00' '1988-05-28 00:00:00' '1988-06-01 00:00:00' ...
#  '1992-02-27 00:00:00' '1992-07-30 00:00:00' '1992-07-28 00:00:00']
#
# haem: estimated platelets x 10^9/L (Hi)
# [nan '441' '379' '423' '286' '205' '258' '308' '215' '207' '221' '319'
#  '275' '345' '71' '105' '20' '330' '540' '404' '263' '479' '821' '398'
#  '223' '193' '42' '292' '277' '560' '311' '349' '247' '361' '300' '513'
#  '419' '238' '320' '253' '108' '157' '374' '257' '351' '278' '14/hpf'
#  '229' '395' '198' '118' '322' '167' '340' '385' '296' '366' '139' '224'
#  '158' '427' '456' '276' '421' '337' '270' '352' '350' '334' '144' '298'
#  '293' '317' '363' '282' '283' '409' '318' '228' '233' '315' '242' '285'
#  '512' '579' '412' '418' '396' '365' '327' '93' '70' '69' '236' '237'
#  '313' '509' '219' '119' '359' '230' '30' '309' '211' '256' '194' '380'
#  '273' '255' '208' '183' '227' '213' '182' '372' '280' '408' '239' '127'
#  '310' '268' '378' '324' '357' '417' '440' '426' '111' '325' '432' '559'
#  '392' '593' '444' '447' '490' '214' '210' '614' '547' '460' '121' '271'
#  '437' '377' '485' '328' '225' '86' '493']
#
# biochem: Low USG?
# [False True nan]
#
# biochem: Hypercreatininaemia?
# [False True nan]
#
# biochem: Anaemic? <25
# [False nan True]
#
# biochem: Hyperphosphataemia? >2_9 to 3
# [False nan True]
#
# biochem: Bilirubin
# [nan '2' '4' '3' '6' '1' '7' '9' '8' '5' '0.9918' '0' '1.6' '8.5' '11'
#  '0.5' '5.301' '2.2059' '9.05' '9.07' '22' '6.1' '18' '10.3' '82.5' '1.1'
#  '1.2' '4.5' '13' '2.2' '1.3' '2.4' '1.8' '40.1' '27' '0.8' '<8.5' '9.7'
#  '17.2' '40' '66' '114' '4.0014' '<5' '0.2' '6.3954' '0.7011' '1.5' '1.9'
#  '0.3' '12' '10' '44.2' '8.69' '3.5' '4.7' '1.7' '4.2' '2.9' '16' '5.6943'
#  '4.0' '6.4' '3.42' '1.4' '3.7' '9.9' '12.5' '2.6' '1.0' '9.2' '2.5'
#  '2.1033' '3.6081' '51' '169' '17' '81' '4.6' '1.71' '2.1' '3.4' '7.524'
#  '4.8' '14' '47' '5.2' '6.99' '4.99' '87' '3.6' '3.2' '15' '56' '41' '65'
#  '49' '31' '20' '4.9932']
#
# urine: Low USG?
# [False True nan]
#
# urine: Azotaemia?
# [False True nan]
#
# urine: Proteinuric UPC  greater 0:4
# [False nan True]
#
# urine: glucose (Multistix)
# ['trace' nan 'nil' 'negative' '3+' '1+' '2+' '4+']
#
# urine: bilirubin (Multistix)
# ['nil' nan 'negative' 'trace' '1+' '4+' '3+' '2+']
#
# urine: ketones (Multistix)
# ['nil' nan 'negative' 'trace' '1+' '2+' '3+' '4+']
#
# urine: blood (Hb -Multistix)
# ['nil' nan 'trace' '3+' 'negative' '2+' '4+' '1+' '12' '0' '5+'
#  'moderate 80']
#
# urine: protein (Multistix)
# ['1+' nan '3+' 'trace' '4+' '2+' 'nil' 'negative']
#
# urine: Positive urine culture
# [False nan True]
#
# urine: leukocytes (/cumm)x
# [nan 'negative' 'trace' '1+' '4+' '3+' '2+' '1-2/hpf' 'nil' '>200/hpf'
#  '50-100/hpf' '<5/hpf']
#
# urine: blood (RBC/ ul) (haematuriax
# [nan '3' '270 x 10^6/L' '0' '>100' '<10' '8' '50' '4+' '<5' '0-3' '30' '2'
#  '1+' '20' '110' '10' '270' '180' '>1000' '40' '3+' '600' '0-2/hpf' '<3'
#  '35' '>500' 'nil' '5/hpf' '1-4/hpf' '4-6/hpf' '1/hpf' '150/hpf' '450'
#  '100' '230' '300' '400' '990' '1800' '70' '150' '100-200/hpf'
#  '100-200/hof' '50-100' '6' '80' '10-100' '28000' '>200' '330' '320' '5-8'
#  '30-50' '660' '160' '2+' '100  x 10^6/L' '60 x 10^6/L' '360 x 10^6/L'
#  '50-100/hpf' '250' '15/hpf' '20-30' '15-20' '10-50' '>>100' '5'
#  '>1000 x 10^6/L' '33/hpf' '18' '<1' '10-20' '200' '5-10' '60']
#
# urine: Lipid
# [False nan True]
#
# urine: Casts
# [False nan True]
#
# urine: Epith cells
# [False nan True]
#
# urine: Crystals
# [False nan True]
#
# urine: Organisms
# [False nan True]
#
# urine: Contaminants?
# [False nan True]
#
# Date dt
# ['1987-02-02' '1988-05-28' '1988-06-01' ... '1992-02-27' '1992-07-30'
#  '1992-07-28']
#
# Date of Birth dt
# ['1974-01-01' '1977-04-27' '1980-12-23' '1991-11-30' '1984-06-30'
#  '1997-01-06' '1999-11-02' '2003-05-12' '2007-09-19' '1978-02-07'
#  '1990-11-27' '1981-01-24' '1995-05-30' '1995-10-26' '1967-01-01'
#  '1993-01-01' '1967-01-22' '1972-07-21' '1973-05-11' '1973-11-02'
#  '1975-11-20' '1976-08-05' '1977-08-27' '1977-07-05' '1978-03-26'
#  '1979-12-30' '1979-02-07' '1979-03-01' '1978-05-25' '1980-01-06'
#  '1980-12-01' '1978-11-08' '1981-01-16' '1981-02-27' '1981-10-01'
#  '1980-03-20' '1973-02-22' '1982-12-22' '1982-04-24' '1983-03-24'
#  '1983-12-05' '1984-12-28' '1980-10-30' '1983-12-01' '1984-02-13'
#  '1983-06-04' '1985-09-07' '1984-07-31' '1986-12-20' '1986-01-31'
#  '1987-06-11' '1983-04-18' '1988-10-09' '1986-02-05' '1980-02-27'
#  '1981-10-21' '1987-09-28' '1989-03-29' '1989-06-01' '1988-08-12'
#  '1988-06-03' '1989-07-12' '1989-11-12' '1988-12-07' '1983-06-18'
#  '1990-01-24' '1990-11-01' '1992-11-08' '1975-10-10' '1992-09-12'
#  '1983-07-01' '1990-07-18' '1990-06-17' '1994-11-02' '1994-12-22'
#  '1988-03-09' '1988-07-29' '1991-05-12' '1993-09-22' '1991-12-16'
#  '1994-05-18' '1985-10-16' '1994-08-15' '1991-04-28' '1996-11-15'
#  '1985-06-30' '1996-06-15' '1990-07-27' '1994-06-21' '1998-10-23'
#  '1997-07-06' '1995-10-03' '1992-09-07' '1998-10-22' '1994-12-30'
#  '1996-09-14' '1995-12-01' '1996-09-18' '1996-01-02' '1996-04-21'
#  '2000-11-21' '1997-11-24' '2000-09-14' '2000-12-31' '2003-03-22'
#  '2002-05-12' '2005-06-05' '2000-07-29' '1999-07-20' '2002-01-12'
#  '1988-10-22' '2002-03-30' '1999-09-29' '1997-03-02' '1990-09-06'
#  '2002-02-14' '2004-09-11' '2006-10-28' '2008-08-05' '2008-08-07'
#  '1996-12-04' '2000-08-22' '2005-03-26' '2009-11-27' '1991-07-01']
#
# age at visit
# ['4780 days 00:00:00.000000000' '5261 days 00:00:00.000000000'
#  '5265 days 00:00:00.000000000' ... '241 days 00:00:00.000000000'
#  '395 days 00:00:00.000000000' '393 days 00:00:00.000000000']

# %%
data_more_than1visit['haem: estimated platelets x 10^9/L (Hi)'] = data_more_than1visit['haem: estimated platelets x 10^9/L (Hi)'].replace({'14/hpf':np.nan}).astype('float')
data_more_than1visit['biochem: Bilirubin'] = data_more_than1visit['biochem: Bilirubin'].str.replace('<','').astype('float')
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Make booleans 1, 0

# %%
bool_to_0_1 =['biochem: Low USG?', 'biochem: Hypercreatininaemia?','biochem: Anaemic? <25', 
              'biochem: Hyperphosphataemia? >2_9 to 3', 'urine: Low USG?', 'urine: Azotaemia?', 
              'urine: Proteinuric UPC  greater 0:4', 'urine: Positive urine culture', 
              'urine: Lipid', 'urine: Casts', 'urine: Epith cells', 'urine: Crystals', 
              'urine: Organisms', 'urine: Contaminants?']

# %%
data_more_than1visit[bool_to_0_1] = data_more_than1visit[bool_to_0_1].replace({True: 1, False: 0})
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %% [markdown]
# #### Convert some ages to days to make them continuous

# %%
data_more_than1visit['age at visit days'] = pd.to_timedelta(data_more_than1visit['age at visit']).dt.days
data_more_than1visit['Age at Death days'] = pd.to_timedelta(data_more_than1visit['Age at Death']).dt.days
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Feature engineering of ordinal variables

# %%
ordinals = ['urine: bilirubin (Multistix)', 'urine: ketones (Multistix)', 'urine: glucose (Multistix)', 
            'urine: blood (Hb -Multistix)', 'urine: pH', 'urine: protein (Multistix)']

# %% [markdown]
# ### urine: bilirubin (Multistix)

# %%
bilirubin_dict = {'nil': 0, 'negative': 0, 'trace': 0, '1+': 20, '2+': 40, '3+': 100, '4+': 100} # this scaling came from ruth's feline medicine book
feature_dict = bilirubin_dict

# %%
feature = 'urine: bilirubin (Multistix)'
data_more_than1visit.loc[:,feature] = data_more_than1visit[feature].replace(feature_dict).copy()
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data_more_than1visit[feature].value_counts()
# Out:
# 0.0      554
# 20.0      19
# 100.0     11
# 40.0       4
# Name: urine: bilirubin (Multistix), dtype: int64

# %% [markdown]
# ### urine: ketones (Multistix)

# %%
feature = ordinals[1]
data_more_than1visit[[feature]][feature].value_counts()
# Out:
# nil         528
# negative     23
# 1+           16
# 3+           13
# trace        11
# 2+            8
# 4+            2
# Name: urine: ketones (Multistix), dtype: int64

# %%
ketones_dict = {'nil': 0, 'negative': 0, 'trace': 5, '1+': 15, '2+': 40, '3+': 80, '4+': 160}
feature_dict = ketones_dict

# %%
data_more_than1visit.loc[:,feature] = data_more_than1visit[feature].replace(feature_dict).copy()
data_more_than1visit[feature].value_counts()
# Out:
# 0.0      551
# 15.0      16
# 80.0      13
# 5.0       11
# 40.0       8
# 160.0      2
# Name: urine: ketones (Multistix), dtype: int64

# %% [markdown]
# ### urine: glucose (Multistix)

# %%
feature = ordinals[2]
data_more_than1visit[[feature]][feature].value_counts()
# Out:
# nil         527
# trace        26
# negative     24
# 2+           16
# 1+            8
# 3+            6
# 4+            6
# Name: urine: glucose (Multistix), dtype: int64

# %%
glucose_dict = {'nil': 0, 'negative': 0, 'trace': 5, '1+': 15, '2+': 30, '3+': 60, '4+': 110}
feature_dict = glucose_dict
data_more_than1visit.loc[:,feature] = data_more_than1visit[feature].replace(feature_dict).copy()
data_more_than1visit[feature].value_counts()
# Out:
# 0.0      551
# 5.0       26
# 30.0      16
# 15.0       8
# 110.0      6
# 60.0       6
# Name: urine: glucose (Multistix), dtype: int64

# %% [markdown]
# ### urine: blood (Hb -Multistix)
# Assumption that all values are hemolysed unless there is a trace amount of intact red blood cells.  CHECK WITH VET.
# - Assumed that trace hemolyzed is the same as non-hemalysed trace (10)
# - Guessed 4+, 5+ are 400

# %%
feature = ordinals[3]
data_more_than1visit[[feature]][feature].value_counts()
# Out:
# nil            213
# 4+             117
# 3+              97
# 2+              68
# trace           67
# 1+              54
# negative         7
# 0                2
# 12               1
# 5+               1
# moderate 80      1
# Name: urine: blood (Hb -Multistix), dtype: int64

# %%
blood_dict = {'nil': 0, 'negative': 0, 'trace': 10, '1+': 25, '2+': 80, '3+': 200, '4+': 400, '5+':500, '12':12, 'moderate 80': 80}
feature_dict = blood_dict
data_more_than1visit.loc[:,feature] = data_more_than1visit[feature].replace(feature_dict).copy()
data_more_than1visit[feature].value_counts()
# Out:
# 0      220
# 400    117
# 200     97
# 80      69
# 10      67
# 25      54
# 0        2
# 500      1
# 12       1
# Name: urine: blood (Hb -Multistix), dtype: int64

# %%
#data_more_than1visit[data_more_than1visit['urine: blood haemolysed']==1]

# %% [markdown]
# ### urine: pH (nothing to do here)

# %%
feature = ordinals[4]
data_more_than1visit[[feature]][feature].value_counts()
# Out:
# 6.0    219
# 6.5    127
# 5.0     64
# 7.0     61
# 8.5     51
# 7.5     43
# 8.0     37
# 9.0     30
# 5.5     14
# 8.8      1
# 6.2      1
# Name: urine: pH, dtype: int64

# %% [markdown]
# ### urine: protein (Multistix)

# %%
feature = ordinals[5]
data_more_than1visit[[feature]][feature].value_counts()
# Out:
# 1+          215
# 2+          183
# 3+          117
# trace        59
# 4+           45
# nil          45
# negative      6
# Name: urine: protein (Multistix), dtype: int64

# %%
protein_dict = {'nil': 0, 'negative': 0, 'trace': 10, '1+': 30, '2+': 100, '3+': 300, '4+': 2000}
feature_dict = protein_dict
data_more_than1visit.loc[:,feature] = data_more_than1visit[feature].replace(feature_dict).copy()
data_more_than1visit[feature].value_counts()
# Out:
# 30.0      215
# 100.0     183
# 300.0     117
# 10.0       59
# 0.0        51
# 2000.0     45
# Name: urine: protein (Multistix), dtype: int64

# %% [markdown]
# ## Min/max scaling

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# %%
scale_list = list(data_more_than1visit.describe().columns)
scale_list.remove('num visits')
scale_list.remove('num key features missing')
scale_list.remove('usg_maxed_out')
scale_list.remove('urine: blood haemolysed')
scale_list
# Out:
# ['haem: RBC (x 10^12/L)',
#  'haem: haemoglobin (g/L)',
#  'haem: HCT (%)',
#  'haem: Total Protein (refractometer)',
#  'haem: leukocyte count (x10^9/L)',
#  'haem: neutrophils (%)',
#  'haem: neutrophils (band)',
#  'haem: neutrophils(seg) (x10^9/L)',
#  'haem: lymphocytes (x10^9/L)',
#  'haem: lymphocytes  (%)',
#  'haem: monocytes (x10^9/L)',
#  'haem: monocytes (%)',
#  'haem: eosinophils  (x10^9/L)',
#  'haem: eosinophils (%)',
#  'haem: estimated platelets x 10^9/L (Hi)',
#  'haem: MCV (fL)',
#  'haem: MCHC (g/L)',
#  'haem: MCH (pg)',
#  'biochem: Low USG?',
#  'biochem: BUN (mmol/L)',
#  'biochem: Hypercreatininaemia?',
#  'biochem: Creatinine (umol/L)',
#  'biochem: Total Plasma Protein (g/L)',
#  'biochem: Serum Albumin (g/L)',
#  'biochem: Globulins (g/L)',
#  'biochem: Anaemic? <25',
#  'biochem: Haematocrit (%)',
#  'biochem: Potassium (mmol/L)',
#  'biochem: Calcium (mmol/L)',
#  'biochem: Hyperphosphataemia? >2_9 to 3',
#  'biochem: Phosphate (mmol/L)',
#  'biochem: Sodium (mmol/L)',
#  'biochem: Chloride (mmol/L)',
#  'biochem: Bicarbonate',
#  'biochem: Glucose',
#  'biochem: CK (U/L)',
#  'biochem: ALP (U/L)',
#  'biochem: ALT (U/L)',
#  'biochem: AST',
#  'biochem: Amylase',
#  'biochem: Cholesterol (mmol/L)',
#  'biochem: Bilirubin',
#  'urine: Urine Specific Gravity',
#  'urine: Low USG?',
#  'urine: Azotaemia?',
#  'urine: Urine protein (g/L)',
#  'urine: urine creatinine (umol/l)',
#  'urine: Protein:creatinine ratio',
#  'urine: Proteinuric UPC  greater 0:4',
#  'urine: glucose (Multistix)',
#  'urine: bilirubin (Multistix)',
#  'urine: ketones (Multistix)',
#  'urine: pH',
#  'urine: protein (Multistix)',
#  'urine: Positive urine culture',
#  'urine: Lipid',
#  'urine: Casts',
#  'urine: Epith cells',
#  'urine: Crystals',
#  'urine: Organisms',
#  'urine: Contaminants?',
#  'age at visit days',
#  'Age at Death days']

# %%
data_scaled = data_more_than1visit.copy()
data_scaled[scale_list] = min_max_scaler.fit_transform(data_scaled[scale_list])

# %%
data_scaled.describe()
# Out:
#        haem: RBC (x 10^12/L)  haem: haemoglobin (g/L)  haem: HCT (%)  \
# count             288.000000               430.000000     452.000000
# mean                0.489518                 0.126871       0.608306
# std                 0.178749                 0.066192       0.156595
# min                 0.000000                 0.000000       0.000000
# 25%                 0.375000                 0.104016       0.500000
# 50%                 0.493956                 0.125129       0.625000
# 75%                 0.604396                 0.145211       0.729167
# max                 1.000000                 1.000000       1.000000
#
#        haem: Total Protein (refractometer)  haem: leukocyte count (x10^9/L)  \
# count                           247.000000                       443.000000
# mean                              0.625479                         0.217276
# std                               0.110017                         0.135100
# min                               0.000000                         0.000000
# 25%                               0.579186                         0.129541
# 50%                               0.619910                         0.183633
# 75%                               0.665158                         0.258184
# max                               1.000000                         1.000000
#
#        haem: neutrophils (%)  haem: neutrophils (band)  \
# count             284.000000                128.000000
# mean                0.720527                  0.237482
# std                 0.145121                  0.160098
# min                 0.000000                  0.000000
# 25%                 0.641975                  0.147841
# 50%                 0.740741                  0.230897
# 75%                 0.827160                  0.302326
# max                 1.000000                  1.000000
#
#        haem: neutrophils(seg) (x10^9/L)  haem: lymphocytes (x10^9/L)  \
# count                        309.000000                   342.000000
# mean                           0.257142                     0.187373
# std                            0.184814                     0.136175
# min                            0.000000                     0.000000
# 25%                            0.142290                     0.098214
# 50%                            0.232426                     0.153061
# 75%                            0.340420                     0.226020
# max                            1.000000                     1.000000
#
#        haem: lymphocytes  (%)  haem: monocytes (x10^9/L)  haem: monocytes (%)  \
# count              227.000000                 327.000000           206.000000
# mean                 0.344356                   0.099218             0.179612
# std                  0.220973                   0.110570             0.134156
# min                  0.000000                   0.000000             0.000000
# 25%                  0.168831                   0.038314             0.105263
# 50%                  0.298701                   0.063218             0.157895
# 75%                  0.506494                   0.125479             0.250000
# max                  1.000000                   1.000000             1.000000
#
#        haem: eosinophils  (x10^9/L)  haem: eosinophils (%)  \
# count                    286.000000             190.000000
# mean                       0.106606               0.139158
# std                        0.131745               0.130418
# min                        0.000000               0.000000
# 25%                        0.030303               0.057143
# 50%                        0.060606               0.114286
# 75%                        0.121212               0.171429
# max                        1.000000               1.000000
#
#        haem: estimated platelets x 10^9/L (Hi)  haem: MCV (fL)  \
# count                               182.000000      116.000000
# mean                                  0.354234        0.137834
# std                                   0.155720        0.116267
# min                                   0.000000        0.000000
# 25%                                   0.256554        0.112179
# 50%                                   0.345818        0.121795
# 75%                                   0.449126        0.137821
# max                                   1.000000        1.000000
#
#        haem: MCHC (g/L)  haem: MCH (pg)  biochem: Low USG?  \
# count        125.000000       66.000000        1046.000000
# mean           0.659664        0.389141           0.172084
# std            0.111129        0.219858           0.377634
# min            0.000000        0.000000           0.000000
# 25%            0.638344        0.270833           0.000000
# 50%            0.664488        0.333333           0.000000
# 75%            0.690632        0.500000           0.000000
# max            1.000000        1.000000           1.000000
#
#        biochem: BUN (mmol/L)  biochem: Hypercreatininaemia?  \
# count            1026.000000                    1046.000000
# mean                0.132686                       0.118547
# std                 0.112928                       0.323409
# min                 0.000000                       0.000000
# 25%                 0.072727                       0.000000
# 50%                 0.099174                       0.000000
# 75%                 0.142975                       0.000000
# max                 1.000000                       1.000000
#
#        biochem: Creatinine (umol/L)  biochem: Total Plasma Protein (g/L)  \
# count                   1024.000000                          1021.000000
# mean                       0.072759                             0.328978
# std                        0.076838                             0.086193
# min                        0.000000                             0.000000
# 25%                        0.042353                             0.284553
# 50%                        0.055731                             0.325203
# 75%                        0.075329                             0.373984
# max                        1.000000                             1.000000
#
#        biochem: Serum Albumin (g/L)  biochem: Globulins (g/L)  \
# count                    982.000000                972.000000
# mean                       0.435595                  0.344322
# std                        0.081357                  0.097270
# min                        0.000000                  0.000000
# 25%                        0.400000                  0.290000
# 50%                        0.440000                  0.330000
# 75%                        0.466667                  0.400000
# max                        1.000000                  1.000000
#
#        biochem: Anaemic? <25  biochem: Haematocrit (%)  \
# count            1046.000000                922.000000
# mean                0.024857                  0.500398
# std                 0.155762                  0.138303
# min                 0.000000                  0.000000
# 25%                 0.000000                  0.418182
# 50%                 0.000000                  0.509091
# 75%                 0.000000                  0.600000
# max                 1.000000                  1.000000
#
#        biochem: Potassium (mmol/L)  biochem: Calcium (mmol/L)  \
# count                   855.000000                 862.000000
# mean                      0.064495                   0.484615
# std                       0.037119                   0.058639
# min                       0.000000                   0.000000
# 25%                       0.053571                   0.450980
# 50%                       0.062500                   0.481373
# 75%                       0.071429                   0.511765
# max                       1.000000                   1.000000
#
#        biochem: Hyperphosphataemia? >2_9 to 3  biochem: Phosphate (mmol/L)  \
# count                             1046.000000                   876.000000
# mean                                 0.004780                     0.160190
# std                                  0.069006                     0.094528
# min                                  0.000000                     0.000000
# 25%                                  0.000000                     0.113043
# 50%                                  0.000000                     0.141304
# 75%                                  0.000000                     0.176087
# max                                  1.000000                     1.000000
#
#        biochem: Sodium (mmol/L)  biochem: Chloride (mmol/L)  \
# count                841.000000                  777.000000
# mean                   0.464069                    0.473659
# std                    0.077585                    0.101875
# min                    0.000000                    0.000000
# 25%                    0.419355                    0.416667
# 50%                    0.467742                    0.483333
# 75%                    0.516129                    0.533333
# max                    1.000000                    1.000000
#
#        biochem: Bicarbonate  biochem: Glucose  biochem: CK (U/L)  \
# count            542.000000        718.000000         894.000000
# mean               0.396510          0.013795           0.009643
# std                0.123942          0.037194           0.048599
# min                0.000000          0.000000           0.000000
# 25%                0.311475          0.009405           0.001554
# 50%                0.409836          0.011514           0.002571
# 75%                0.475410          0.014669           0.004917
# max                1.000000          1.000000           1.000000
#
#        biochem: ALP (U/L)  biochem: ALT (U/L)  biochem: AST  biochem: Amylase  \
# count          904.000000          977.000000    903.000000        336.000000
# mean             0.028877            0.020796      0.025298          0.309011
# std              0.062793            0.047263      0.050098          0.212748
# min              0.000000            0.000000      0.000000          0.000000
# 25%              0.008705            0.007563      0.008511          0.159566
# 50%              0.014690            0.012606      0.013678          0.236974
# 75%              0.026115            0.021430      0.025228          0.461737
# max              1.000000            1.000000      1.000000          1.000000
#
#        biochem: Cholesterol (mmol/L)  biochem: Bilirubin  \
# count                     554.000000          726.000000
# mean                        0.065800            0.031542
# std                         0.046465            0.065348
# min                         0.000000            0.000000
# 25%                         0.047368            0.011834
# 50%                         0.061513            0.017751
# 75%                         0.080263            0.029586
# max                         1.000000            1.000000
#
#        urine: Urine Specific Gravity  urine: Low USG?  urine: Azotaemia?  \
# count                     710.000000        750.00000         750.000000
# mean                        0.040238          0.36000           0.094667
# std                         0.061559          0.48032           0.292949
# min                         0.000000          0.00000           0.000000
# 25%                         0.026451          0.00000           0.000000
# 50%                         0.037453          0.00000           0.000000
# 75%                         0.046816          1.00000           0.000000
# max                         1.000000          1.00000           1.000000
#
#        urine: Urine protein (g/L)  urine: urine creatinine (umol/l)  \
# count                   60.000000                         60.000000
# mean                     0.019503                          0.281170
# std                      0.129521                          0.204342
# min                      0.000000                          0.000000
# 25%                      0.000151                          0.139647
# 50%                      0.000286                          0.196155
# 75%                      0.000641                          0.412368
# max                      1.000000                          1.000000
#
#        urine: Protein:creatinine ratio  urine: Proteinuric UPC  greater 0:4  \
# count                        67.000000                           750.000000
# mean                          0.044411                             0.018667
# std                           0.123339                             0.135435
# min                           0.000000                             0.000000
# 25%                           0.010281                             0.000000
# 50%                           0.013913                             0.000000
# 75%                           0.033703                             0.000000
# max                           1.000000                             1.000000
#
#        urine: glucose (Multistix)  urine: bilirubin (Multistix)  \
# count                  613.000000                    588.000000
# mean                     0.025953                      0.027891
# std                      0.119673                      0.142636
# min                      0.000000                      0.000000
# 25%                      0.000000                      0.000000
# 50%                      0.000000                      0.000000
# 75%                      0.000000                      0.000000
# max                      1.000000                      1.000000
#
#        urine: ketones (Multistix)   urine: pH  urine: protein (Multistix)  \
# count                  601.000000  648.000000                  670.000000
# mean                     0.020539    0.409144                    0.112269
# std                      0.097021    0.267192                    0.243587
# min                      0.000000    0.000000                    0.000000
# 25%                      0.000000    0.250000                    0.015000
# 50%                      0.000000    0.375000                    0.050000
# 75%                      0.000000    0.531250                    0.050000
# max                      1.000000    1.000000                    1.000000
#
#        urine: Positive urine culture  urine: Lipid  urine: Casts  \
# count                     750.000000     750.00000    750.000000
# mean                        0.045333       0.04000      0.046667
# std                         0.208173       0.19609      0.211065
# min                         0.000000       0.00000      0.000000
# 25%                         0.000000       0.00000      0.000000
# 50%                         0.000000       0.00000      0.000000
# 75%                         0.000000       0.00000      0.000000
# max                         1.000000       1.00000      1.000000
#
#        urine: Epith cells  urine: Crystals  urine: Organisms  \
# count          750.000000       750.000000        750.000000
# mean             0.050667         0.125333          0.117333
# std              0.219462         0.331317          0.322032
# min              0.000000         0.000000          0.000000
# 25%              0.000000         0.000000          0.000000
# 50%              0.000000         0.000000          0.000000
# 75%              0.000000         0.000000          0.000000
# max              1.000000         1.000000          1.000000
#
#        urine: Contaminants?  usg_maxed_out  urine: blood haemolysed  \
# count            750.000000    1404.000000              1404.000000
# mean               0.037333       0.123219                 0.005698
# std                0.189704       0.328806                 0.075297
# min                0.000000       0.000000                 0.000000
# 25%                0.000000       0.000000                 0.000000
# 50%                0.000000       0.000000                 0.000000
# 75%                0.000000       0.000000                 0.000000
# max                1.000000       1.000000                 1.000000
#
#         num visits  num key features missing  age at visit days  \
# count  1404.000000               1404.000000        1404.000000
# mean     16.452991                  1.034188           0.431212
# std      11.803448                  0.793038           0.218326
# min       2.000000                  0.000000           0.000000
# 25%       7.000000                  0.000000           0.270782
# 50%      15.000000                  1.000000           0.447181
# 75%      20.000000                  2.000000           0.585306
# max      53.000000                  3.000000           1.000000
#
#        Age at Death days
# count        1282.000000
# mean            0.583751
# std             0.195104
# min             0.000000
# 25%             0.499658
# 50%             0.582573
# 75%             0.708599
# max             1.000000

# %% [markdown]
# ## One hot encoding

# %%
features_to_one_hot_encode = ['Sex', 'Species (common name)']

# %%
data_scaled = pd.get_dummies(data_scaled, columns = features_to_one_hot_encode)

# %%
# drop the male sex column (we don't need both)
data_scaled.drop(columns=['Sex_male'], inplace = True)

# %% [markdown]
# ## Mkae the dtypes what we want them to be

# %%
data_scaled.select_dtypes(include=['object']).columns
# Out:
# Index(['ARKS Number', 'Age at Death', 'Date  of Birth', 'Date',
#        'urine: blood (Hb -Multistix)', 'urine: leukocytes (/cumm)x',
#        'urine: blood (RBC/ ul) (haematuriax', 'Date dt', 'Date of Birth dt',
#        'age at visit'],
#       dtype='object')

# %%
data_scaled['urine: blood (Hb -Multistix)'].value_counts()
# Out:
# 0      220
# 400    117
# 200     97
# 80      69
# 10      67
# 25      54
# 0        2
# 500      1
# 12       1
# Name: urine: blood (Hb -Multistix), dtype: int64

# %% [markdown]
# ## Write scaled data to csv

# %%
filename = '../Data/big_cats/processed_data/scaled_data_15_09_2021.csv'
data_scaled.to_csv(filename, index=False)

# %%
import pickle
data_scaled_dtypes = data_scaled.dtypes.to_dict()
filename = '../Data/big_cats/processed_data/scaled_data_dtypes_15_09_2021.pkl'

with open(filename, 'wb') as handle:
    pickle.dump(data_scaled_dtypes, handle)

# %% [markdown]
# # Correlation

# %%
cols_we_want = list(data_scaled.select_dtypes(include=['float', 'int']).columns)
cols_we_want.remove('num visits')
cols_we_want.remove('num key features missing')
cols_we_want.remove('Age at Death days')
cols_we_want
# Out:
# ['haem: RBC (x 10^12/L)',
#  'haem: haemoglobin (g/L)',
#  'haem: HCT (%)',
#  'haem: Total Protein (refractometer)',
#  'haem: leukocyte count (x10^9/L)',
#  'haem: neutrophils (%)',
#  'haem: neutrophils (band)',
#  'haem: neutrophils(seg) (x10^9/L)',
#  'haem: lymphocytes (x10^9/L)',
#  'haem: lymphocytes  (%)',
#  'haem: monocytes (x10^9/L)',
#  'haem: monocytes (%)',
#  'haem: eosinophils  (x10^9/L)',
#  'haem: eosinophils (%)',
#  'haem: estimated platelets x 10^9/L (Hi)',
#  'haem: MCV (fL)',
#  'haem: MCHC (g/L)',
#  'haem: MCH (pg)',
#  'biochem: Low USG?',
#  'biochem: BUN (mmol/L)',
#  'biochem: Hypercreatininaemia?',
#  'biochem: Creatinine (umol/L)',
#  'biochem: Total Plasma Protein (g/L)',
#  'biochem: Serum Albumin (g/L)',
#  'biochem: Globulins (g/L)',
#  'biochem: Anaemic? <25',
#  'biochem: Haematocrit (%)',
#  'biochem: Potassium (mmol/L)',
#  'biochem: Calcium (mmol/L)',
#  'biochem: Hyperphosphataemia? >2_9 to 3',
#  'biochem: Phosphate (mmol/L)',
#  'biochem: Sodium (mmol/L)',
#  'biochem: Chloride (mmol/L)',
#  'biochem: Bicarbonate',
#  'biochem: Glucose',
#  'biochem: CK (U/L)',
#  'biochem: ALP (U/L)',
#  'biochem: ALT (U/L)',
#  'biochem: AST',
#  'biochem: Amylase',
#  'biochem: Cholesterol (mmol/L)',
#  'biochem: Bilirubin',
#  'urine: Urine Specific Gravity',
#  'urine: Low USG?',
#  'urine: Azotaemia?',
#  'urine: Urine protein (g/L)',
#  'urine: urine creatinine (umol/l)',
#  'urine: Protein:creatinine ratio',
#  'urine: Proteinuric UPC  greater 0:4',
#  'urine: glucose (Multistix)',
#  'urine: bilirubin (Multistix)',
#  'urine: ketones (Multistix)',
#  'urine: pH',
#  'urine: protein (Multistix)',
#  'urine: Positive urine culture',
#  'urine: Lipid',
#  'urine: Casts',
#  'urine: Epith cells',
#  'urine: Crystals',
#  'urine: Organisms',
#  'urine: Contaminants?',
#  'usg_maxed_out',
#  'urine: blood haemolysed',
#  'age at visit days']

# %%
check_corr_df = data_scaled[cols_we_want]

# %%
import seaborn as sns
cormat = check_corr_df.corr()
#round(cormat,2)
sns.heatmap(cormat)

# %%
upper_corr_mat = cormat.where(
    np.triu(np.ones(cormat.shape), k=1).astype(np.bool))
  
# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()
  
# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values()
sorted_mat_df = sorted_mat.to_frame(name='correlation')
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
sorted_mat_df['correlation abs'] = np.abs(sorted_mat_df['correlation'])

# %%
sorted_mat_df[sorted_mat_df['correlation abs'] > 0.8].sort_values(by = 'correlation abs', ascending = False)
# Out:
#                                                                          correlation  \
# urine: urine creatinine (umol/l)    haem: Total Protein (refractometer)    -1.000000
# urine: Urine protein (g/L)          haem: Total Protein (refractometer)     1.000000
# urine: Protein:creatinine ratio     haem: Total Protein (refractometer)     1.000000
# biochem: Haematocrit (%)            haem: HCT (%)                           0.980644
# urine: Urine protein (g/L)          haem: MCH (pg)                         -0.979809
#                                     haem: MCV (fL)                         -0.921730
# urine: Urine Specific Gravity       haem: haemoglobin (g/L)                 0.902753
# haem: eosinophils (%)               haem: eosinophils  (x10^9/L)            0.887506
# urine: Protein:creatinine ratio     haem: neutrophils (band)                0.884727
# haem: neutrophils(seg) (x10^9/L)    haem: leukocyte count (x10^9/L)         0.865467
# haem: monocytes (%)                 haem: monocytes (x10^9/L)               0.841687
# biochem: Globulins (g/L)            biochem: Total Plasma Protein (g/L)     0.840865
# biochem: Total Plasma Protein (g/L) haem: Total Protein (refractometer)     0.827698
# urine: Protein:creatinine ratio     haem: monocytes (x10^9/L)               0.826581
# haem: lymphocytes  (%)              haem: neutrophils (%)                  -0.821273
# urine: Protein:creatinine ratio     haem: leukocyte count (x10^9/L)         0.815837
# urine: Azotaemia?                   biochem: Hypercreatininaemia?           0.809551
# urine: Low USG?                     biochem: Low USG?                       0.807748
# haem: MCH (pg)                      haem: MCV (fL)                          0.800932
#
#                                                                          correlation abs
# urine: urine creatinine (umol/l)    haem: Total Protein (refractometer)         1.000000
# urine: Urine protein (g/L)          haem: Total Protein (refractometer)         1.000000
# urine: Protein:creatinine ratio     haem: Total Protein (refractometer)         1.000000
# biochem: Haematocrit (%)            haem: HCT (%)                               0.980644
# urine: Urine protein (g/L)          haem: MCH (pg)                              0.979809
#                                     haem: MCV (fL)                              0.921730
# urine: Urine Specific Gravity       haem: haemoglobin (g/L)                     0.902753
# haem: eosinophils (%)               haem: eosinophils  (x10^9/L)                0.887506
# urine: Protein:creatinine ratio     haem: neutrophils (band)                    0.884727
# haem: neutrophils(seg) (x10^9/L)    haem: leukocyte count (x10^9/L)             0.865467
# haem: monocytes (%)                 haem: monocytes (x10^9/L)                   0.841687
# biochem: Globulins (g/L)            biochem: Total Plasma Protein (g/L)         0.840865
# biochem: Total Plasma Protein (g/L) haem: Total Protein (refractometer)         0.827698
# urine: Protein:creatinine ratio     haem: monocytes (x10^9/L)                   0.826581
# haem: lymphocytes  (%)              haem: neutrophils (%)                       0.821273
# urine: Protein:creatinine ratio     haem: leukocyte count (x10^9/L)             0.815837
# urine: Azotaemia?                   biochem: Hypercreatininaemia?               0.809551
# urine: Low USG?                     biochem: Low USG?                           0.807748
# haem: MCH (pg)                      haem: MCV (fL)                              0.800932

# %%
data_scaled.describe()
# Out:
#        haem: RBC (x 10^12/L)  haem: haemoglobin (g/L)  haem: HCT (%)  \
# count             288.000000               430.000000     452.000000
# mean                0.489518                 0.126871       0.608306
# std                 0.178749                 0.066192       0.156595
# min                 0.000000                 0.000000       0.000000
# 25%                 0.375000                 0.104016       0.500000
# 50%                 0.493956                 0.125129       0.625000
# 75%                 0.604396                 0.145211       0.729167
# max                 1.000000                 1.000000       1.000000
#
#        haem: Total Protein (refractometer)  haem: leukocyte count (x10^9/L)  \
# count                           247.000000                       443.000000
# mean                              0.625479                         0.217276
# std                               0.110017                         0.135100
# min                               0.000000                         0.000000
# 25%                               0.579186                         0.129541
# 50%                               0.619910                         0.183633
# 75%                               0.665158                         0.258184
# max                               1.000000                         1.000000
#
#        haem: neutrophils (%)  haem: neutrophils (band)  \
# count             284.000000                128.000000
# mean                0.720527                  0.237482
# std                 0.145121                  0.160098
# min                 0.000000                  0.000000
# 25%                 0.641975                  0.147841
# 50%                 0.740741                  0.230897
# 75%                 0.827160                  0.302326
# max                 1.000000                  1.000000
#
#        haem: neutrophils(seg) (x10^9/L)  haem: lymphocytes (x10^9/L)  \
# count                        309.000000                   342.000000
# mean                           0.257142                     0.187373
# std                            0.184814                     0.136175
# min                            0.000000                     0.000000
# 25%                            0.142290                     0.098214
# 50%                            0.232426                     0.153061
# 75%                            0.340420                     0.226020
# max                            1.000000                     1.000000
#
#        haem: lymphocytes  (%)  haem: monocytes (x10^9/L)  haem: monocytes (%)  \
# count              227.000000                 327.000000           206.000000
# mean                 0.344356                   0.099218             0.179612
# std                  0.220973                   0.110570             0.134156
# min                  0.000000                   0.000000             0.000000
# 25%                  0.168831                   0.038314             0.105263
# 50%                  0.298701                   0.063218             0.157895
# 75%                  0.506494                   0.125479             0.250000
# max                  1.000000                   1.000000             1.000000
#
#        haem: eosinophils  (x10^9/L)  haem: eosinophils (%)  \
# count                    286.000000             190.000000
# mean                       0.106606               0.139158
# std                        0.131745               0.130418
# min                        0.000000               0.000000
# 25%                        0.030303               0.057143
# 50%                        0.060606               0.114286
# 75%                        0.121212               0.171429
# max                        1.000000               1.000000
#
#        haem: estimated platelets x 10^9/L (Hi)  haem: MCV (fL)  \
# count                               182.000000      116.000000
# mean                                  0.354234        0.137834
# std                                   0.155720        0.116267
# min                                   0.000000        0.000000
# 25%                                   0.256554        0.112179
# 50%                                   0.345818        0.121795
# 75%                                   0.449126        0.137821
# max                                   1.000000        1.000000
#
#        haem: MCHC (g/L)  haem: MCH (pg)  biochem: Low USG?  \
# count        125.000000       66.000000        1046.000000
# mean           0.659664        0.389141           0.172084
# std            0.111129        0.219858           0.377634
# min            0.000000        0.000000           0.000000
# 25%            0.638344        0.270833           0.000000
# 50%            0.664488        0.333333           0.000000
# 75%            0.690632        0.500000           0.000000
# max            1.000000        1.000000           1.000000
#
#        biochem: BUN (mmol/L)  biochem: Hypercreatininaemia?  \
# count            1026.000000                    1046.000000
# mean                0.132686                       0.118547
# std                 0.112928                       0.323409
# min                 0.000000                       0.000000
# 25%                 0.072727                       0.000000
# 50%                 0.099174                       0.000000
# 75%                 0.142975                       0.000000
# max                 1.000000                       1.000000
#
#        biochem: Creatinine (umol/L)  biochem: Total Plasma Protein (g/L)  \
# count                   1024.000000                          1021.000000
# mean                       0.072759                             0.328978
# std                        0.076838                             0.086193
# min                        0.000000                             0.000000
# 25%                        0.042353                             0.284553
# 50%                        0.055731                             0.325203
# 75%                        0.075329                             0.373984
# max                        1.000000                             1.000000
#
#        biochem: Serum Albumin (g/L)  biochem: Globulins (g/L)  \
# count                    982.000000                972.000000
# mean                       0.435595                  0.344322
# std                        0.081357                  0.097270
# min                        0.000000                  0.000000
# 25%                        0.400000                  0.290000
# 50%                        0.440000                  0.330000
# 75%                        0.466667                  0.400000
# max                        1.000000                  1.000000
#
#        biochem: Anaemic? <25  biochem: Haematocrit (%)  \
# count            1046.000000                922.000000
# mean                0.024857                  0.500398
# std                 0.155762                  0.138303
# min                 0.000000                  0.000000
# 25%                 0.000000                  0.418182
# 50%                 0.000000                  0.509091
# 75%                 0.000000                  0.600000
# max                 1.000000                  1.000000
#
#        biochem: Potassium (mmol/L)  biochem: Calcium (mmol/L)  \
# count                   855.000000                 862.000000
# mean                      0.064495                   0.484615
# std                       0.037119                   0.058639
# min                       0.000000                   0.000000
# 25%                       0.053571                   0.450980
# 50%                       0.062500                   0.481373
# 75%                       0.071429                   0.511765
# max                       1.000000                   1.000000
#
#        biochem: Hyperphosphataemia? >2_9 to 3  biochem: Phosphate (mmol/L)  \
# count                             1046.000000                   876.000000
# mean                                 0.004780                     0.160190
# std                                  0.069006                     0.094528
# min                                  0.000000                     0.000000
# 25%                                  0.000000                     0.113043
# 50%                                  0.000000                     0.141304
# 75%                                  0.000000                     0.176087
# max                                  1.000000                     1.000000
#
#        biochem: Sodium (mmol/L)  biochem: Chloride (mmol/L)  \
# count                841.000000                  777.000000
# mean                   0.464069                    0.473659
# std                    0.077585                    0.101875
# min                    0.000000                    0.000000
# 25%                    0.419355                    0.416667
# 50%                    0.467742                    0.483333
# 75%                    0.516129                    0.533333
# max                    1.000000                    1.000000
#
#        biochem: Bicarbonate  biochem: Glucose  biochem: CK (U/L)  \
# count            542.000000        718.000000         894.000000
# mean               0.396510          0.013795           0.009643
# std                0.123942          0.037194           0.048599
# min                0.000000          0.000000           0.000000
# 25%                0.311475          0.009405           0.001554
# 50%                0.409836          0.011514           0.002571
# 75%                0.475410          0.014669           0.004917
# max                1.000000          1.000000           1.000000
#
#        biochem: ALP (U/L)  biochem: ALT (U/L)  biochem: AST  biochem: Amylase  \
# count          904.000000          977.000000    903.000000        336.000000
# mean             0.028877            0.020796      0.025298          0.309011
# std              0.062793            0.047263      0.050098          0.212748
# min              0.000000            0.000000      0.000000          0.000000
# 25%              0.008705            0.007563      0.008511          0.159566
# 50%              0.014690            0.012606      0.013678          0.236974
# 75%              0.026115            0.021430      0.025228          0.461737
# max              1.000000            1.000000      1.000000          1.000000
#
#        biochem: Cholesterol (mmol/L)  biochem: Bilirubin  \
# count                     554.000000          726.000000
# mean                        0.065800            0.031542
# std                         0.046465            0.065348
# min                         0.000000            0.000000
# 25%                         0.047368            0.011834
# 50%                         0.061513            0.017751
# 75%                         0.080263            0.029586
# max                         1.000000            1.000000
#
#        urine: Urine Specific Gravity  urine: Low USG?  urine: Azotaemia?  \
# count                     710.000000        750.00000         750.000000
# mean                        0.040238          0.36000           0.094667
# std                         0.061559          0.48032           0.292949
# min                         0.000000          0.00000           0.000000
# 25%                         0.026451          0.00000           0.000000
# 50%                         0.037453          0.00000           0.000000
# 75%                         0.046816          1.00000           0.000000
# max                         1.000000          1.00000           1.000000
#
#        urine: Urine protein (g/L)  urine: urine creatinine (umol/l)  \
# count                   60.000000                         60.000000
# mean                     0.019503                          0.281170
# std                      0.129521                          0.204342
# min                      0.000000                          0.000000
# 25%                      0.000151                          0.139647
# 50%                      0.000286                          0.196155
# 75%                      0.000641                          0.412368
# max                      1.000000                          1.000000
#
#        urine: Protein:creatinine ratio  urine: Proteinuric UPC  greater 0:4  \
# count                        67.000000                           750.000000
# mean                          0.044411                             0.018667
# std                           0.123339                             0.135435
# min                           0.000000                             0.000000
# 25%                           0.010281                             0.000000
# 50%                           0.013913                             0.000000
# 75%                           0.033703                             0.000000
# max                           1.000000                             1.000000
#
#        urine: glucose (Multistix)  urine: bilirubin (Multistix)  \
# count                  613.000000                    588.000000
# mean                     0.025953                      0.027891
# std                      0.119673                      0.142636
# min                      0.000000                      0.000000
# 25%                      0.000000                      0.000000
# 50%                      0.000000                      0.000000
# 75%                      0.000000                      0.000000
# max                      1.000000                      1.000000
#
#        urine: ketones (Multistix)   urine: pH  urine: protein (Multistix)  \
# count                  601.000000  648.000000                  670.000000
# mean                     0.020539    0.409144                    0.112269
# std                      0.097021    0.267192                    0.243587
# min                      0.000000    0.000000                    0.000000
# 25%                      0.000000    0.250000                    0.015000
# 50%                      0.000000    0.375000                    0.050000
# 75%                      0.000000    0.531250                    0.050000
# max                      1.000000    1.000000                    1.000000
#
#        urine: Positive urine culture  urine: Lipid  urine: Casts  \
# count                     750.000000     750.00000    750.000000
# mean                        0.045333       0.04000      0.046667
# std                         0.208173       0.19609      0.211065
# min                         0.000000       0.00000      0.000000
# 25%                         0.000000       0.00000      0.000000
# 50%                         0.000000       0.00000      0.000000
# 75%                         0.000000       0.00000      0.000000
# max                         1.000000       1.00000      1.000000
#
#        urine: Epith cells  urine: Crystals  urine: Organisms  \
# count          750.000000       750.000000        750.000000
# mean             0.050667         0.125333          0.117333
# std              0.219462         0.331317          0.322032
# min              0.000000         0.000000          0.000000
# 25%              0.000000         0.000000          0.000000
# 50%              0.000000         0.000000          0.000000
# 75%              0.000000         0.000000          0.000000
# max              1.000000         1.000000          1.000000
#
#        urine: Contaminants?  usg_maxed_out  urine: blood haemolysed  \
# count            750.000000    1404.000000              1404.000000
# mean               0.037333       0.123219                 0.005698
# std                0.189704       0.328806                 0.075297
# min                0.000000       0.000000                 0.000000
# 25%                0.000000       0.000000                 0.000000
# 50%                0.000000       0.000000                 0.000000
# 75%                0.000000       0.000000                 0.000000
# max                1.000000       1.000000                 1.000000
#
#         num visits  num key features missing  age at visit days  \
# count  1404.000000               1404.000000        1404.000000
# mean     16.452991                  1.034188           0.431212
# std      11.803448                  0.793038           0.218326
# min       2.000000                  0.000000           0.000000
# 25%       7.000000                  0.000000           0.270782
# 50%      15.000000                  1.000000           0.447181
# 75%      20.000000                  2.000000           0.585306
# max      53.000000                  3.000000           1.000000
#
#        Age at Death days  Sex_female  Species (common name)_African Lion  \
# count        1282.000000  1404.00000                         1404.000000
# mean            0.583751     0.44302                            0.057692
# std             0.195104     0.49692                            0.233244
# min             0.000000     0.00000                            0.000000
# 25%             0.499658     0.00000                            0.000000
# 50%             0.582573     0.00000                            0.000000
# 75%             0.708599     1.00000                            0.000000
# max             1.000000     1.00000                            1.000000
#
#        Species (common name)_Asiatic Lion  Species (common name)_Bengal Tiger  \
# count                         1404.000000                         1404.000000
# mean                             0.036325                            0.046296
# std                              0.187164                            0.210201
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            0.000000
# max                              1.000000                            1.000000
#
#        Species (common name)_Bengal Tiger (white)  \
# count                                 1404.000000
# mean                                     0.005698
# std                                      0.075297
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        Species (common name)_Bobcat  Species (common name)_Caracal  \
# count                   1404.000000                    1404.000000
# mean                       0.015670                       0.034900
# std                        0.124238                       0.183593
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        0.000000                       0.000000
# max                        1.000000                       1.000000
#
#        Species (common name)_Cheetah  Species (common name)_Clouded Leopard  \
# count                    1404.000000                            1404.000000
# mean                        0.282764                               0.030627
# std                         0.450503                               0.172366
# min                         0.000000                               0.000000
# 25%                         0.000000                               0.000000
# 50%                         0.000000                               0.000000
# 75%                         1.000000                               0.000000
# max                         1.000000                               1.000000
#
#        Species (common name)_Cougar  Species (common name)_Fishing Cat  \
# count                   1404.000000                        1404.000000
# mean                       0.018519                           0.064103
# std                        0.134865                           0.245023
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        0.000000                           0.000000
# max                        1.000000                           1.000000
#
#        Species (common name)_Jaguar  Species (common name)_Jaguarundi  \
# count                   1404.000000                       1404.000000
# mean                       0.045584                          0.004274
# std                        0.208656                          0.065255
# min                        0.000000                          0.000000
# 25%                        0.000000                          0.000000
# 50%                        0.000000                          0.000000
# 75%                        0.000000                          0.000000
# max                        1.000000                          1.000000
#
#        Species (common name)_Leopard  Species (common name)_Leopard Cat  \
# count                    1404.000000                        1404.000000
# mean                        0.008547                           0.003561
# std                         0.092087                           0.059591
# min                         0.000000                           0.000000
# 25%                         0.000000                           0.000000
# 50%                         0.000000                           0.000000
# 75%                         0.000000                           0.000000
# max                         1.000000                           1.000000
#
#        Species (common name)_Lion  \
# count                 1404.000000
# mean                     0.023504
# std                      0.151553
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.000000
# max                      1.000000
#
#        Species (common name)_Northern (Canadian) Lynx  \
# count                                     1404.000000
# mean                                         0.003561
# std                                          0.059591
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        Species (common name)_Ocelot  Species (common name)_Persian Leopard  \
# count                   1404.000000                            1404.000000
# mean                       0.053419                               0.007835
# std                        0.224947                               0.088198
# min                        0.000000                               0.000000
# 25%                        0.000000                               0.000000
# 50%                        0.000000                               0.000000
# 75%                        0.000000                               0.000000
# max                        1.000000                               1.000000
#
#        Species (common name)_Serval  Species (common name)_Siberian Tiger  \
# count                   1404.000000                           1404.000000
# mean                       0.042023                              0.002849
# std                        0.200713                              0.053319
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        0.000000                              0.000000
# 75%                        0.000000                              0.000000
# max                        1.000000                              1.000000
#
#        Species (common name)_Snow Leopard  \
# count                         1404.000000
# mean                             0.080484
# std                              0.272138
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Species (common name)_Sumatran Tiger  \
# count                           1404.000000
# mean                               0.079772
# std                                0.271037
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        Species (common name)_Temminck's Golden Cat  \
# count                                  1404.000000
# mean                                      0.031339
# std                                       0.174294
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        Species (common name)_Tiger  Species (common name)_Tiger (White)
# count                  1404.000000                          1404.000000
# mean                      0.011396                             0.009259
# std                       0.106180                             0.095813
# min                       0.000000                             0.000000
# 25%                       0.000000                             0.000000
# 50%                       0.000000                             0.000000
# 75%                       0.000000                             0.000000
# max                       1.000000                             1.000000
