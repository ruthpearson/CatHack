# %%
import pandas as pd
# %matplotlib inline

# %%
file = '../Data/big_cats/processed_data/merged_tables_tol_14days_2021-03-25.csv'
data = pd.read_csv(file)
data
# Out:
#       haem: ID ARKS No haem: Animal Name                 Date  \
# 0        464.0  670005           Quintus  1988-05-08 00:00:00
# 1        463.0  670005           Quintus  1988-05-20 00:00:00
# 2        462.0  670005           Quintus  1988-05-25 00:00:00
# 3        388.0  750011             X-Ray  1989-03-07 00:00:00
# 4        551.0  A20046            Ovambo  1989-09-29 00:00:00
# 5        547.0  A20047            Nakuru  1989-09-29 00:00:00
# 6        470.0  880014          Claudius  1989-11-24 00:00:00
# 7        135.0  880014          Claudius  1989-11-28 00:00:00
# 8        389.0  750011             X-Ray  1990-05-31 00:00:00
# 9        390.0  750011             X-Ray  1990-07-24 00:00:00
# 10       327.0  930228             Kutch  1991-01-11 00:00:00
# 11       326.0  930228             Kutch  1991-01-26 00:00:00
# 12       414.0  850007               Gus  1991-04-25 00:00:00
# 13       648.0  820029             Kashi  1991-07-05 00:00:00
# ...

# %%
data['haem biochem date diff'].hist(bins = 15)

# %%
data['haem urine date diff'].hist(bins = 15)

# %%
data['urine biochem date diff'].hist(bins = 15)
