# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import numpy as np

# %%
columns = ['Database Name', 'Patient Number', 'Client Number', 'Consultation Number', 'Item Name', 'Units',
           'Item Label', 'Clinic Code', 'Consulting Vet', 'Patient Desexed', 'Deceased Date',
           'Visit Date', 'Consultation Date', 'Examination Text' ,'Patient Species', 'Patient Breed',
           'Patient Colour', 'Patient Sex', 'Patient Date of Birth', 'Insured', 'weight', 'temperature',
           'HeartRate', 'BodyScore', 'DentalGrade', 'RespRate', 'PainScore', 'BP', 'CRT', 'MMColour']

# %%
data_dir = "../Data/vet_compass/"
data = pd.read_csv(data_dir + 'STR024A03 20190719 sample x10,000.csv', header=None, names = columns)
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,2,3,19,20,21,22,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(6)
# Out:
#   Database Name Patient Number Client Number Consultation Number Item Name  \
# 0         RxNSW        7138614           NaN            13869415       NaN
# 1         RxNSW        7737653           NaN            22925726       NaN
# 2         RxNSW        7738120           NaN            22934344       NaN
# 3         RxNSW        7745004           NaN            23043653       NaN
# 4         RxNSW        7742894           NaN            23043708       NaN
# 5         RxNSW        7776041           NaN            23594489       NaN
#
#    Units Item Label  Clinic Code Consulting Vet  Patient Desexed  \
# 0    NaN        NaN            1            WA1                1
# 1    NaN        NaN            1            ZOU                1
# 2    NaN        NaN            1            ZOU                1
# 3    NaN        NaN            1            ZOU                1
# 4    NaN        NaN            1            ZOU                1
# 5    NaN        NaN            1            BRZ                1
#
#              Deceased Date               Visit Date        Consultation Date  \
# 0                      NaN  2012-07-05 17:09:03.000  2012-07-05 17:09:03.000
# 1                      NaN  2003-04-25 00:00:00.000  2003-04-25 00:00:00.000
# 2                      NaN  2004-01-10 00:00:00.000  2004-01-10 00:00:00.000
# 3                      NaN  2013-02-18 16:47:52.000  2013-02-18 16:47:52.000
# 4  2013-11-05 10:00:34.000  2013-02-20 08:40:38.000  2013-02-20 08:40:38.000
# 5                      NaN  2007-10-08 18:00:00.000  2007-10-08 18:00:00.000
#
#                                     Examination Text Patient Species  \
# 0  -------------------- Fees Charged: -----------...             Cat
# 1                                                NaN             Cat
# 2                                                NaN             Cat
# 3                                                NaN             Cat
# 4                                  Dental; Renal  Dz             Cat
# 5                                        Lab  Report             Cat
#
#           Patient Breed  Patient Colour Patient Sex    Patient Date of Birth  \
# 0               Persian           White      Female  2010-07-05 00:00:00.000
# 1             Tonkinese           Lilac        Male  2002-11-26 00:00:00.000
# 2  Domestic Medium Hair   Tortoiseshell      Female  2003-02-14 00:00:00.000
# 3               Siamese     Lilac Point        Male  2008-07-20 00:00:00.000
# 4    Domestic Long Hair  Ginger & White        Male  1994-03-16 00:00:00.000
# 5               Burmese           Cream        Male  2005-12-05 00:00:00.000
#
#   Insured weight temperature HeartRate BodyScore DentalGrade RespRate  \
# 0     NaN    NaN         NaN       NaN       NaN         NaN      NaN
# 1     NaN    NaN         NaN       NaN       NaN         NaN      NaN
# 2     NaN    NaN         NaN       NaN       NaN         NaN      NaN
# 3     NaN    NaN         NaN       NaN       NaN         NaN      NaN
# 4     NaN    NaN         NaN       NaN       NaN         NaN      NaN
# 5     NaN    NaN         NaN       NaN       NaN         NaN      NaN
#
#   PainScore   BP  CRT MMColour
# 0       NaN  NaN  NaN      NaN
# 1       NaN  NaN  NaN      NaN
# 2       NaN  NaN  NaN      NaN
# 3       NaN  NaN  NaN      NaN
# 4       NaN  NaN  NaN      NaN
# 5       NaN  NaN  NaN      NaN

# %%
len(set(data["Patient Number"]))
# Out:
# 10627

# %%
data[pd.notnull(data["Deceased Date"])]
# Out:
#        Database Name Patient Number Client Number Consultation Number  \
# 4              RxNSW        7742894           NaN            23043708
# 42             RxNSW        6077526   6.41324e+06            10838997
# 43             RxNSW        6077526    6.4219e+06            10838997
# 44             RxNSW        6077182   6.41313e+06            10841087
# 51             RxNSW        6083813   6.41247e+06            10859526
# ...              ...            ...           ...                 ...
# 722492         RxVIC        7780785   1.23044e+07            18320964
# 722493         RxVIC        7780785   1.23044e+07            18320964
# 722494         RxVIC        7780785   1.23044e+07            18320964
# 722495         RxVIC        7700495    1.2261e+07            18321788
# 722496         RxVIC        7700495    1.2261e+07            18321788
#
#                               Item Name  Units Item Label  Clinic Code  \
# 4                                   NaN    NaN        NaN            1
# 42                        Grooming Fees    1.0        NaN          102
# 43                        Grooming Fees    1.0        NaN          102
# 44        E9 Standard Consult  Wyoming     1.0        NaN          102
# 51                                  NaN    NaN        NaN          102
# ...                                 ...    ...        ...          ...
# 722492                   PAK-Euthanasia    1.0        NaN          243
# 722493                    RES-Exam Room   30.0        NaN          243
# 722494                   VAR-Euthanasia    6.8        NaN          243
# 722495   Edenhills Cremation Small <9kg    1.0        NaN          243
# 722496  Edenhills Wooden Box With Photo    1.0        NaN          243
#
#        Consulting Vet  Patient Desexed            Deceased Date  \
# 4                 ZOU                1  2013-11-05 10:00:34.000
# 42                ANY                1  2017-12-11 00:00:00.000
# 43                ANY                1  2017-12-11 00:00:00.000
# 44                CTK                1  2017-03-23 00:00:00.000
# 51                TG1                1  2018-07-23 00:00:00.000
# ...               ...              ...                      ...
# 722492            DC3                1  2018-04-30 00:00:00.000
# 722493            DC3                1  2018-04-30 00:00:00.000
# 722494            DC3                1  2018-04-30 00:00:00.000
# 722495            TBC                1  2018-05-01 00:00:00.000
# 722496            TBC                1  2018-05-01 00:00:00.000
#
#                      Visit Date        Consultation Date  \
# 4       2013-02-20 08:40:38.000  2013-02-20 08:40:38.000
# 42      2011-03-17 08:51:01.000  2011-03-17 08:51:01.000
# 43      2011-03-17 08:51:01.000  2011-03-17 08:51:01.000
# 44      2011-03-18 11:07:24.000  2011-03-18 11:07:24.000
# 51      2011-03-31 09:01:25.000  2011-03-31 09:01:25.000
# ...                         ...                      ...
# 722492  2018-04-30 14:27:36.000  2018-04-30 14:27:36.000
# 722493  2018-04-30 14:27:36.000  2018-04-30 14:27:36.000
# 722494  2018-04-30 14:27:36.000  2018-04-30 14:27:36.000
# 722495  2018-05-01 08:11:10.000  2018-05-01 08:11:10.000
# 722496  2018-05-01 08:11:10.000  2018-05-01 08:11:10.000
#
#                                          Examination Text Patient Species  \
# 4                                       Dental; Renal  Dz             Cat
# 42      History: Examination: Laboratory: Assessment: ...             Cat
# 43      History: Examination: Laboratory: Assessment: ...             Cat
# 44      Reason: 11- Unwell Appointment Notes: Overdue ...             Cat
# 51                                  Vaccination  Reaction             Cat
# ...                                                   ...             ...
# 722492  Reason: Health Check Appointment Notes: V+; dr...             Cat
# 722493  Reason: Health Check Appointment Notes: V+; dr...             Cat
# 722494  Reason: Health Check Appointment Notes: V+; dr...             Cat
# 722495  Was okay sunday; went downhill rapidly yesterd...             Cat
# 722496  Was okay sunday; went downhill rapidly yesterd...             Cat
#
#                Patient Breed  Patient Colour Patient Sex  \
# 4         Domestic Long Hair  Ginger & White        Male
# 42       Domestic Short Hair   Tortoiseshell      Female
# 43       Domestic Short Hair   Tortoiseshell      Female
# 44      Domestic Medium Hair   Tortoiseshell      Female
# 51       Domestic Short Hair           Tabby        Male
# ...                      ...             ...         ...
# 722492    Domestic Long Hair          Tabbie      Female
# 722493    Domestic Long Hair          Tabbie      Female
# 722494    Domestic Long Hair          Tabbie      Female
# 722495   Domestic Short Hair          (none)      Female
# 722496   Domestic Short Hair          (none)      Female
#
#           Patient Date of Birth Insured weight temperature HeartRate  \
# 4       1994-03-16 00:00:00.000     NaN    NaN         NaN       NaN
# 42      2002-04-01 00:00:00.000     NaN    NaN         NaN       NaN
# 43      2002-04-01 00:00:00.000     NaN    NaN         NaN       NaN
# 44      2002-02-02 00:00:00.000     NaN    NaN         NaN       NaN
# 51                          NaN     NaN    NaN         NaN       NaN
# ...                         ...     ...    ...         ...       ...
# 722492  1998-10-19 00:00:00.000     NaN   2.74         NaN       NaN
# 722493  1998-10-19 00:00:00.000     NaN   2.74         NaN       NaN
# 722494  1998-10-19 00:00:00.000     NaN   2.74         NaN       NaN
# 722495  2005-08-07 00:00:00.000     NaN    NaN         NaN       NaN
# 722496  2005-08-07 00:00:00.000     NaN    NaN         NaN       NaN
#
#        BodyScore DentalGrade RespRate PainScore   BP  CRT MMColour
# 4            NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 42           NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 43           NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 44           NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 51           NaN         NaN      NaN       NaN  NaN  NaN      NaN
# ...          ...         ...      ...       ...  ...  ...      ...
# 722492       NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 722493       NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 722494       NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 722495       NaN         NaN      NaN       NaN  NaN  NaN      NaN
# 722496       NaN         NaN      NaN       NaN  NaN  NaN      NaN
#
# [83934 rows x 30 columns]

# %%
data.iloc[77]['Examination Text']
# Out:
# 'History: Examination: Laboratory: Assessment: Treatment: Plan: bath &  nails'

# %%
data['Examination Text']
# Out:
# 0         -------------------- Fees Charged: -----------...
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                         Dental; Renal  Dz
#                                 ...
# 722644    Reason: Check Up. Appointment Notes: Overdue r...
# 722645    Reason: Check Up. Appointment Notes: Overdue r...
# 722646    Reason: Check Up. Appointment Notes: Overdue r...
# 722647    Reason: Check Up. Appointment Notes: Overdue r...
# 722648                                        In house  use
# Name: Examination Text, Length: 722649, dtype: object

# %%
data[data['Visit Date']== pd.date_time('1988-02-19')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-380f733aa192> in <module>
# ----> 1 data[data['Visit Date']== pd.date_time('1988-02-19')]
#
# /usr/local/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#
# AttributeError: module 'pandas' has no attribute 'date_time'

# %%
data['Examination Text'].str.contains("renal").value_counts()
# Out:
# False    584855
# True      19568
# Name: Examination Text, dtype: int64

# %%
data[data['Examination Text'].str.contains("renal")==True].iloc[2199]['Examination Text']
# Out:
# "Original Vet : Dr Lynn Mathison; B.V.Sc (Hons); MANZCVSc (Veterinary Behaviour) (N5531) Reason: MEDICAL - Kidney Disease Appointment Notes: renal sachets TREATMENT: (AM) LM --- 03/03/2018 08:27:58 LM: Cleaned; and Fed: urinated and eaten. No faeces passed. Examine: T:38.4. BAR in himself. Iv fluids stopped. Restarted @ 20mls/hr Medications given: Nil this morning. IV fluids: DAY 3/3. 500mls started treatment Plan: AM (LM) to run bloods pm and discuss with owners Owners Visited: --- 03/03/2018 11:50:44 JT: Spoke to owners - given update Plan is to reassess bloods again this evening --- 03/03/2018 17:22:17 LM: Monitoring: blood taken Laboratory: BUN = 333 (was 587) CREA = 18.7 (was 41.7) Assessment: imrpovement but not normal yet. I would leave on iv fluids longer. Plan: discuss with owners at visit. --- 03/03/2018 17:53:45 LM: Owners Visited: Discussed that levels better; and as improving; i would continue on iv fluids for another 48hrs and retest. Kaitlin's boyfriend is going to help with costs; so will keep going with treatment. Cleaned; and Fed: (pm) --- 03/03/2018 ~18:05:50 RM: Eating; Drinking; Urinating. RM Treatment: Clav 0.55mls sc given. Iv fluids running well - total of 200mls since last treatment. Eating tinned k/d well (found a donated tin). -------------------- Fees Charged: -------------------- Trans.Iv Daily Fee 0-15kg Qty: 1 Sale Price $103.90 Hospitalisation High Dependency Cat Qty: 1 Sale Price $116.00 Veterinary Medical/Surgical Examination In Hospital Qty: 1 Sale Price $15.80 Discount Qty: 1 Sale Price $-11.80 CREA Reagent IDEXX - IN HOUSE Qty: 1 Sale Price $23.80 BUN Reagent IDEXX - IN HOUSE Qty: 1 Sale Price $23.80 Clavulox Injection (40ml Bottle) Qty: 0.55 Sale Price  $28.10"
