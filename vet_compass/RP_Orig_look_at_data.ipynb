# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
columns = ['Database Name', 'Patient Number', 'Client Number', 'Consultation Number', 'Item Name', 'Units',
           'Item Label', 'Clinic Code', 'Consulting Vet', 'Patient Desexed', 'Deceased Date',
           'Visit Date', 'Consultation Date', 'Examination Text' ,'Patient Species', 'Patient Breed',
           'Patient Colour', 'Patient Sex', 'Patient Date of Birth', 'Insured', 'weight', 'temperature',
           'HeartRate', 'BodyScore', 'DentalGrade', 'RespRate', 'PainScore', 'BP', 'CRT', 'MMColour']

# %%
data_dir = '../Data/vet_compass/'
data = pd.read_csv(data_dir + 'STR024A03 20190719 sample x10,000.csv', header=None, names = columns)
# Out:
# /Users/ruth/miniconda3/envs/vetAI/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (1,2,3,19,20,21,22,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(6)
# Out:
#   Database Name Patient Number Client Number Consultation Number Item Name  \
# 0         RxNSW        7138614           NaN            13869415       NaN
# 1         RxNSW        7737653           NaN            22925726       NaN
# 2         RxNSW        7738120           NaN            22934344       NaN
# 3         RxNSW        7745004           NaN            23043653       NaN
# 4         RxNSW        7742894           NaN            23043708       NaN
# 5         RxNSW        7776041           NaN            23594489       NaN
#
#    Units Item Label  Clinic Code Consulting Vet  Patient Desexed  \
# 0    NaN        NaN            1            WA1                1
# 1    NaN        NaN            1            ZOU                1
# 2    NaN        NaN            1            ZOU                1
# 3    NaN        NaN            1            ZOU                1
# 4    NaN        NaN            1            ZOU                1
# ...

# %%
print('number of records')
print(len(data))
print('number of cats')
print(len(data['Patient Number'].unique()))
# Out:
# number of records
# 722649
# number of cats
# 10627

# %%
data.iloc[1250]['Examination Text']
# Out:
# 'Reason: 9.15app V+ Blood Appointment Notes: nv History: sunday was very quiet lethargic ate very little am ? Re potentially also quiet during last week. History pf gi obstruction 2 yrs ago lethargic sitting outside not doing anything vomiting bile last pm not drinking or eating vomited blood this am Examination: very lethargic dehydrated skin tenting mm slightly pale dry mm abd pain anterior abd t 35.6 Laboratory: Assessment: poss anae;mic gi tract coudnt r/o snake bite / fb or gi irritation Dehydratd and hypothermic Treatment: Plan: admit for iv hartmans bloods pcv and send bloods to xray abd cerenia 0.6 ml scut clavulox 0.3 ml scut 3 pm b temp 37.4 better hydrated brighter xrayed abd nil suggested fb sent bloods urgently continue fluids o/n no vomiting 7 pm brighter t 37.7 hydrated continued fluids 14/10- lethargic T 39.4/?? Abdo palp Catheter blown/ hydrated at moment 0.3 clav Await bloods rmains flat biochem ast slightly elevated fbc clotted ? Repeat fbc here All ok but platelet
# ...

# %%
data['Examination Text']

# %%
data[data['Visit Date']== pd.date_time('1988-02-19')]

# %%
data['Examination Text'].str.contains("renal").value_counts()
# Out:
# False    584855
# True      19568
# Name: Examination Text, dtype: int64

# %%
data[data['Examination Text'].str.contains("renal")==True].iloc[2199]['Examination Text']

# %%
data[data['Patient Number'] == '7725132']['Examination Text']
# Out:
# 687014    History: Examination: Laboratory: Assessment: ...
# 687018                                                  NaN
# 687019                                                  NaN
# 687022    Appointment Notes: Zydax History: Examination:...
# 687025    No petty cash. Required Tacrolimus for client ...
# 687108    Original Vet : Charis N McLean ---------------...
# 687109    Original Vet : Charis N McLean ---------------...
# 687116    Original Vet : Charis N McLean ---------------...
# 687117    Original Vet : Dr. Kirsten Hailstone B.Sc.;B.V...
# 687118    Original Vet : Dr. Kirsten Hailstone B.Sc.;B.V...
# 687119                      Vaccination; worm and prog  inj
# 687120                      Vaccination; worm and prog  inj
# 687121    Original Vet : Leeann Joy Mibus --------------...
# 687122    Original Vet : Dr. Kirsten Hailstone B.Sc.;B.V...
# 687123    Original Vet : Charis N McLean ---------------...
# 687124    Original Vet : Leeann Joy Mibus --------------...
# ...

# %%
data['Database Name'].unique()
# Out:
# array(['RxNSW', 'RxQLD', 'RxVIC'], dtype=object)
